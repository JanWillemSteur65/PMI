# %%
'''
Licensed Materials - Property of IBM
IBM Maximo APM - Predictive Maintenance Insights On-Premises
IBM Maximo APM - Predictive Maintenance Insights SaaS 
© Copyright IBM Corp. 2019 All Rights Reserved.
US Government Users Restricted Rights - Use, duplication or disclosure restricted by GSA ADP Schedule Contract with IBM Corp.
'''
# Out:
# '\nLicensed Materials - Property of IBM\nIBM Maximo APM - Predictive Maintenance Insights On-Premises\nIBM Maximo APM - Predictive Maintenance Insights SaaS \n© Copyright IBM Corp. 2019 All Rights Reserved.\nUS Government Users Restricted Rights - Use, duplication or disclosure restricted by GSA ADP Schedule Contract with IBM Corp.\n'

# %% [markdown]
# # Maximo APM PMI - Predicted Failure Date Model Template

# %% [markdown]
# 1. [Introduction](#introduction)
# 2. [Install Maximo APM PMI SDK](#install-maximo-apm-pmi-sdk)
# 3. [Setup the Model Training Pipeline](#setup-model-training-pipline)
# 4. [Train the Model Instance](#train-model-instance)
# 5. [Register the Trained Model Instance](#register-trained-model-instance)
# 6. [Model Template Internals](#model-template-internals)

# %% [markdown]
# <a id='introduction'></a>
# ## Introduction
#
# ###### Use Case Description
#
# This notebook deals with computing time to failure for a system like a process or a unit task or an asset like a device.
#
# This notebook uses the survival_analysis package of SROM supporting various algorithms to compute the survival functions and median time to failure. The survival analysis package handles both survival and failure analysis.
#
# Survival analysis is a branch of statistics for analyzing the expected duration of time until one or more events happen including, but not limited to, failure in mechanical systems. This topic is called reliability theory or reliability analysis in engineering, duration analysis or duration modelling in economics, and event history analysis in sociology. Survival analysis attempts to answer questions such as: what is the proportion of a sample that will survive past a certain time? Of those that survive, at what rate will they fail?  How do particular circumstances or characteristics or causes increase or decrease the probability of survival or failure?
#
# Broadly speaking, survival analysis involves the modelling of time to event data; in this context involving industrial processes and assets, failure or fault could be considered an "event". The key assumption here is a single event occurs for each subject, after which the subject (asset or a process) is stopped or failed - meaning it ceases to exist or survive.
#
# This model provides several methods for survival/failure analysis, including:
# + Kaplan-Meier Estimator
# + Nelson-Aalen
# + Cox Regression
# + Aalen's Additive Regression Model
#
# The notebook shows the model building, training, and registration to PMI.
#
# **Input Data**
# The raw data for time-to-failure model is from Maximo and IOT platform. First, it gets the asset failure history and the assets' sensor data (the *_episode). Then the raw data will be merged into the format with the columns below -
#
# + id (that indicates the process or the system or an asset)
# + event_timestamp (the timestamp of data points)
# + failuredate (the asset has failure on this date, which is coming from Maximo failure history data)
# + installdate (the installation date of the asset, which is coming from Maximo asset meta data)
# + *_episode (related sensor data to the failure event)
#
# | id  | event_timestamp | faildate |  c_episode | t_episode | f_episode | p_episode| installdate |
# | ------------- |-------------|-------------|-------|------------|------------|------------|------------|
# | SAMPLE_ASSET101-__-BEDFORD | 2018-07-02 | 2018-07-02 | 1 | 7  | 2 | 3| 2017-10-30T00:00:00 |
# | SAMPLE_ASSET101-__-BEDFORD | 2019-03-18 | NaT | 1 | 5  | 2 | 5| 2017-10-30T00:00:00 |
# | SAMPLE_ASSET102-__-BEDFORD | 2019-03-21 | 2019-03-21 | 2 | 8  | 4 | 3| 2017-10-29T00:00:00 |
#
# In the data set above, each row corresponds to a device event. The data contains failure information for the devices. The failuredate means the asset has failure on this date, otherwise it is NaT. The model will calculate the durations between different failure dates for each asset. The remaining columns are covariates which are potentially correlated with failures of devices.
#
# **Output**
#
# The output depends on the type of algorithm that best fits the data. Depending on the case, and as illustrated in this notebook below, the output involves predicting the time to the event of consideration in one of the different forms. For Kaplan Meier, which is a non-parametric method, the value is a the median. It can also give the survival function. But this does not deal with covariates. The key advanatge is this works well for right censoring in the sample.
# For Nelson Aalen, the result is the hazard function. This is also a non-parametric method, and does not take the covariates into consideration.
# For Cox Regression, which is suitable for covariates, the result is hazard function and the expected duration before the event happens. This is a semi-parametric model, and this factors in the role of covariates in the occurrence of the event.

# %% [markdown]
# <a id="install-maximo-apm-pmi-sdk"></a>
# ## Install Maximo APM PMI SDK

# %% [markdown]
# To install the SDK, you need your Maximo APM PMI instance ID, API base URL, and your API key. The Maximo APM PMI instance ID and API base URL can be found in the user welcome letter. For API key, request to your Maximo admin to create an user account first to generate one for you. Create one environment variable for each here.

# %%
# %%capture
# %env APM_ID=4ac3917e
# %env APM_API_BASEURL=https://prod.pmi.apm.maximo.ibm.com
# %env APM_API_KEY=dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f

# %% [markdown]
# Then, install PMI SDK with `pip`. Note that we have to upgrade `pip` first.

# %%
# !pip install -U pip~=18.1
# !pip install pyspark
# !pip install -U https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/4ac3917e/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/lib/download?filename=pmlib-1.0.0.tar.gz
# Out:
# Requirement already up-to-date: pip~=18.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (18.1)
# Requirement already satisfied: pyspark in /opt/conda/envs/Python36/lib/python3.6/site-packages (2.4.5)
# Requirement already satisfied: py4j==0.10.7 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pyspark) (0.10.7)
# Collecting https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/4ac3917e/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/lib/download?filename=pmlib-1.0.0.tar.gz
#   Downloading https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/4ac3917e/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/lib/download?filename=pmlib-1.0.0.tar.gz (792kB)
#     100% |████████████████████████████████| 798kB 56.1MB/s ta 0:00:01
# Requirement already satisfied, skipping upgrade: dill==0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.3.0)
# Requirement already satisfied, skipping upgrade: ibm_db~=3.0.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (3.0.1)
# Requirement already satisfied, skipping upgrade: ibm_db_sa~=0.3.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.3.4)
# Requirement already satisfied, skipping upgrade: ibmdbpy~=0.1.4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.1.5)
# Requirement already satisfied, skipping upgrade: iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0 from https://github.com/ibm-watson-iot/functions/tarball/production_2_0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (2.0.3)
# Requirement already satisfied, skipping upgrade: joblib==0.12.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.12.5)
# Requirement already satisfied, skipping upgrade: lifelines==0.14.6 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.14.6)
# Requirement already satisfied, skipping upgrade: networkx==2.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (2.1)
# Requirement already satisfied, skipping upgrade: numpy~=1.17.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (1.17.5)
# Requirement already satisfied, skipping upgrade: outlier_utils==0.0.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.0.3)
# Requirement already satisfied, skipping upgrade: pandas~=0.24.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.24.1)
# Requirement already satisfied, skipping upgrade: pip~=18.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (18.1)
# Requirement already satisfied, skipping upgrade: requests~=2.18.4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (2.18.4)
# Requirement already satisfied, skipping upgrade: requests_futures~=1.0.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn~=0.20.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.20.3)
# Requirement already satisfied, skipping upgrade: scipy==1.1.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: statsmodels==0.9.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.9.0)
# Requirement already satisfied, skipping upgrade: tsfresh==0.10.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (0.10.1)
# Requirement already satisfied, skipping upgrade: watson-machine-learning-client~=1.0.371 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (1.0.376)
# Requirement already satisfied, skipping upgrade: matplotlib in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pmlib==1.0.0) (3.0.2)
# Requirement already satisfied, skipping upgrade: sqlalchemy>=0.7.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm_db_sa~=0.3.3->pmlib==1.0.0) (1.2.18)
# Requirement already satisfied, skipping upgrade: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibmdbpy~=0.1.4->pmlib==1.0.0) (1.12.0)
# Requirement already satisfied, skipping upgrade: lazy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibmdbpy~=0.1.4->pmlib==1.0.0) (1.4)
# Requirement already satisfied, skipping upgrade: pypyodbc in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibmdbpy~=0.1.4->pmlib==1.0.0) (1.3.4)
# Requirement already satisfied, skipping upgrade: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibmdbpy~=0.1.4->pmlib==1.0.0) (0.17.1)
# Requirement already satisfied, skipping upgrade: lxml==4.3.4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (4.3.4)
# Requirement already satisfied, skipping upgrade: psycopg2-binary>=2.8.4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (2.8.4)
# Requirement already satisfied, skipping upgrade: pyod>=0.7.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.7.8)
# Requirement already satisfied, skipping upgrade: nose>=1.3.7 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (1.3.7)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.16.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.16.2)
# Requirement already satisfied, skipping upgrade: tabulate==0.8.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.8.5)
# Requirement already satisfied, skipping upgrade: urllib3==1.22 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (1.22)
# Requirement already satisfied, skipping upgrade: ibm-cos-sdk==2.1.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (2.1.3)
# Requirement already satisfied, skipping upgrade: decorator>=4.1.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from networkx==2.1->pmlib==1.0.0) (4.3.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas~=0.24.0->pmlib==1.0.0) (2.7.5)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas~=0.24.0->pmlib==1.0.0) (2018.9)
# Requirement already satisfied, skipping upgrade: idna<2.7,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests~=2.18.4->pmlib==1.0.0) (2.6)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests~=2.18.4->pmlib==1.0.0) (2019.11.28)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests~=2.18.4->pmlib==1.0.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: patsy>=0.4.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tsfresh==0.10.1->pmlib==1.0.0) (0.5.1)
# Requirement already satisfied, skipping upgrade: tqdm>=4.10.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from tsfresh==0.10.1->pmlib==1.0.0) (4.31.1)
# Requirement already satisfied, skipping upgrade: lomond in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson-machine-learning-client~=1.0.371->pmlib==1.0.0) (0.3.3)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from matplotlib->pmlib==1.0.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from matplotlib->pmlib==1.0.0) (1.0.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from matplotlib->pmlib==1.0.0) (2.3.1)
# Requirement already satisfied, skipping upgrade: setuptools in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pypyodbc->ibmdbpy~=0.1.4->pmlib==1.0.0) (40.8.0)
# Requirement already satisfied, skipping upgrade: numba>=0.35 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pyod>=0.7.5->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.42.0)
# Requirement already satisfied, skipping upgrade: suod in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pyod>=0.7.5->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.0.3)
# Requirement already satisfied, skipping upgrade: combo in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pyod>=0.7.5->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.1.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-image>=0.16.2->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (1.0.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-image>=0.16.2->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (5.4.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-image>=0.16.2->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (2.4.1)
# Requirement already satisfied, skipping upgrade: ibm-cos-sdk-core==2.*,>=2.0.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk==2.1.3->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (2.4.3)
# Requirement already satisfied, skipping upgrade: ibm-cos-sdk-s3transfer==2.*,>=2.0.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk==2.1.3->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (2.4.3)
# Requirement already satisfied, skipping upgrade: llvmlite>=0.27.0dev0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from numba>=0.35->pyod>=0.7.5->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.27.0)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk-core==2.*,>=2.0.0->ibm-cos-sdk==2.1.3->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.9.3)
# Requirement already satisfied, skipping upgrade: docutils>=0.10 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk-core==2.*,>=2.0.0->ibm-cos-sdk==2.1.3->iotfunctions@ https://github.com/ibm-watson-iot/functions/tarball/production_2_0->pmlib==1.0.0) (0.14)
# Building wheels for collected packages: pmlib
#   Running setup.py bdist_wheel for pmlib ... done
#   Stored in directory: /home/dsxuser/.tmp/pip-ephem-wheel-cache-hwmz161r/wheels/27/e3/4f/8f4f27f0744ea9362917922e6990c31fc7ed89833aa12f6e3a
# Successfully built pmlib
# Installing collected packages: pmlib
#   Found existing installation: pmlib 1.0.0
#     Uninstalling pmlib-1.0.0:
#       Successfully uninstalled pmlib-1.0.0
# Successfully installed pmlib-1.0.0

# %% [markdown]
# <a id="setup-model-training-pipline"></a>
# ## Setup the Model Training Pipeline

# %% [markdown]
# Before you can start working on the model training pipeline, you have to setup an asset group and asset-sensor relationshp properly in Maximo. See IBM Maximo APM - Predictive MaintenanceInsights SaaS User Guide for details.
#
# Required model pipeline configuration:
#
# * Asset group ID: The unit of model processing is an asset group. Asset groups are managed on Maximo APM UI. You need to get the ID of the asset group to be analyzed by this model.
# * Asset failure history and installation date as the label: This model requires asset installation date (Asset attribute **```installdate```** in Maximo) and asset failure history (Asset Workorder attribute **```faildate```** in Maximo) to extract the latel for training.
# * Sensor data as features: This model also accepts one or more features from either asset data or IOT data. **Note that these features must be of type Integer or Floating-Point Number.** Features are specifed simply by attribute names prefixed by type (with separator colon). For asset attribute, the prefix is an empty string. For IOT data attribute, the prefix is the device type registered on Watson IOT Platform.
# * Prediction output names: This model generates one output, the predicted failure date. Give it a name (containing only alphanumeric, dash, and underline).
#
# Now you can setup a training pipeine based on this model template, with your own data, to train a model instance.

# %%
from pmlib.time_to_failure import TimeToFailureAssetGroupPipeline

group = TimeToFailureAssetGroupPipeline(
            asset_group_id='1016', 
            model_pipeline={
                'features': ['IIOT:rh','IIOT:temp','IIOT:pressure','IIOT:flow','IIOT:energy','IIOT:vibration'],
                'features_for_training': [':installdate', ':faildate'],
                'predictions': ['predicted_time_to_failure'],
            })
# Out:
# Warning: confluent_kafka is not installed. Publish to MessageHub not supported.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class GraphLasso is deprecated; The 'GraphLasso' was renamed to 'GraphicalLasso' in version 0.20 and will be removed in 0.22.
#   warnings.warn(msg, category=DeprecationWarning)
# 2020-03-30T09:55:29.751 pmlib.api.init_environ INFO APM_ID=4ac3917e, APM_API_BASEURL=https://prod.pmi.apm.maximo.ibm.com, APM_API_KEY=********
# 2020-03-30T09:55:29.753 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/tenant?instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json=None, session=None, kwargs={}
# 2020-03-30T09:55:31.597 pmlib.util.api_request INFO resp.status_code=200, method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/tenant?instanceId=4ac3917e
# 2020-03-30T09:55:31.599 pmlib.api.init_environ DEBUG resp={
#     "as_apikey": "********",
#     "as_apitoken": "********",
#     "as_id": null,
#     "as_url": "https://api-us.connectedproducts.internetofthings.ibmcloud.com",
#     "info": {
#         "API_BASEURL": "https://api-us.connectedproducts.internetofthings.ibmcloud.com",
#         "API_KEY": "********",
#         "API_TOKEN": "********",
#         "COS_BUCKET_KPI": "analytics-runtime-ctp-pmi-democore-31-7f08111d4f82",
#         "COS_BUCKET_LOGGING": "analytics-logs-ctp-pmi-democore-31-ad6d973f904e",
#         "COS_ENDPOINT": "s3-api.us-geo.objectstorage.softlayer.net",
#         "COS_HMAC_ACCESS_KEY_ID": "********",
#         "COS_HMAC_SECRET_ACCESS_KEY": "********",
#         "COS_REGION": "global",
#         "DB_CONNECTION_STRING": "********",
#         "DB_TYPE": "db2",
#         "MH_BROKERS_SASL": "broker-0-xx3x794gyl7j5jjy.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093",
#         "MH_DEFAULT_ALERT_TOPIC": "analytics-alerts-CTP-PMI-Democore-31",
#         "MH_PASSWORD": "********",
#         "MH_USER": "********",
#         "PMI_CLOUD_TYPE": "PUBLIC",
#         "TENANT_ID": "CTP-PMI-Democore-31"
#     },
#     "keyverified": "true",
#     "mahi_apikey": "********",
#     "mahi_auth_url": "https://demo-iot.znapz.net/maximo/oslc/permission/allowedappoptions?app=RELENGINEER&lean=1",
#     "mahi_id": "4ac3917e",
#     "mahi_url": "https://demo-iot.znapz.net/maximo",
#     "tenant_as_id": "CTP-PMI-Democore-31",
#     "tenant_id": "162",
#     "tenant_mahi_id": null,
#     "tenant_name": "CTP_Democore31",
#     "wml_cred": null
# }
# 2020-03-30T09:55:31.600 pmlib.api.init_environ INFO setting environment variable MAXIMO_BASEURL=https://demo-iot.znapz.net/maximo
# 2020-03-30T09:55:31.601 pmlib.api.init_environ INFO MAXIMO_LINKED=True
# 2020-03-30T09:55:31.602 pmlib.api.init_environ INFO setting environment variable MAXIMO_API_CONTEXT=/oslc
# 2020-03-30T09:55:31.603 pmlib.api.init_environ INFO setting environment variable SSL_VERIFY_APM=True
# 2020-03-30T09:55:31.611 pmlib.api.init_environ INFO setting environment variable SSL_VERIFY_AS=True
# 2020-03-30T09:55:31.612 pmlib.api.init_environ INFO setting environment variable SSL_VERIFY_WIOTP=True
# 2020-03-30T09:55:31.613 pmlib.api.init_environ INFO setting environment variable SSL_VERIFY_MAXIMO=False
# 2020-03-30T09:55:31.614 pmlib.api.init_environ INFO setting environment variable DB_CONNECTION_STRING=********
# 2020-03-30T09:55:31.615 pmlib.api.init_environ INFO setting environment variable COS_BUCKET_KPI=analytics-runtime-ctp-pmi-democore-31-7f08111d4f82
# 2020-03-30T09:55:31.616 pmlib.api.init_environ INFO setting environment variable COS_BUCKET_LOGGING=analytics-logs-ctp-pmi-democore-31-ad6d973f904e
# 2020-03-30T09:55:31.617 pmlib.api.init_environ INFO setting environment variable MH_BROKERS_SASL=broker-0-xx3x794gyl7j5jjy.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093
# 2020-03-30T09:55:31.630 pmlib.api.init_environ INFO setting environment variable API_BASEURL=https://api-us.connectedproducts.internetofthings.ibmcloud.com
# 2020-03-30T09:55:31.632 pmlib.api.init_environ INFO setting environment variable COS_REGION=global
# 2020-03-30T09:55:31.633 pmlib.api.init_environ INFO setting environment variable MH_USER=********
# 2020-03-30T09:55:31.634 pmlib.api.init_environ INFO setting environment variable COS_HMAC_ACCESS_KEY_ID=********
# 2020-03-30T09:55:31.635 pmlib.api.init_environ INFO setting environment variable COS_HMAC_SECRET_ACCESS_KEY=********
# 2020-03-30T09:55:31.635 pmlib.api.init_environ INFO setting environment variable API_TOKEN=********
# 2020-03-30T09:55:31.636 pmlib.api.init_environ INFO setting environment variable DB_TYPE=db2
# 2020-03-30T09:55:31.637 pmlib.api.init_environ INFO setting environment variable API_KEY=********
# 2020-03-30T09:55:31.638 pmlib.api.init_environ INFO setting environment variable PMI_CLOUD_TYPE=PUBLIC
# 2020-03-30T09:55:31.639 pmlib.api.init_environ INFO setting environment variable TENANT_ID=CTP-PMI-Democore-31
# 2020-03-30T09:55:31.651 pmlib.api.init_environ INFO setting environment variable MH_PASSWORD=********
# 2020-03-30T09:55:31.652 pmlib.api.init_environ INFO setting environment variable MH_DEFAULT_ALERT_TOPIC=analytics-alerts-CTP-PMI-Democore-31
# 2020-03-30T09:55:31.653 pmlib.api.init_environ INFO setting environment variable COS_ENDPOINT=https://s3-api.us-geo.objectstorage.softlayer.net
# 2020-03-30T09:55:31.654 pmlib.util.api_request INFO method=put, url=https://api-us.connectedproducts.internetofthings.ibmcloud.com/api/constants/v1/CTP-PMI-Democore-31, headers={'Content-Type': 'application/json', 'X-api-key': '********', 'X-api-token': '********', 'Cache-Control': 'no-cache'}, timeout=30, ssl_verify=True, json=[{'name': 'apm_info', 'entityType': None, 'enabled': True, 'value': {'APM_ID': '4ac3917e', 'APM_API_BASEURL': 'https://prod.pmi.apm.maximo.ibm.com', 'APM_API_KEY': 'dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f'}, 'metadata': {'type': 'CONSTANT', 'dataType': 'LITERAL', 'description': 'APM tenant information.', 'tags': None, 'required': True, 'values': None}}], session=None, kwargs={}
# 2020-03-30T09:55:32.409 pmlib.util.api_request INFO resp.status_code=200, method=put, url=https://api-us.connectedproducts.internetofthings.ibmcloud.com/api/constants/v1/CTP-PMI-Democore-31
# 2020-03-30T09:55:32.410 iotfunctions.db.__init__ DEBUG Unable to locate message_hub credentials. Database object created, but it will not be able interact with message hub.
# 2020-03-30T09:55:32.412 iotfunctions.db.__init__ DEBUG Found connection string in os variables: DATABASE=BLUDB;HOSTNAME=db2w-ssctxwa.us-south.db2w.cloud.ibm.com;PORT=50001;PROTOCOL=TCPIP;UID=bluadmin;PWD=neCsbd2qUWygbymZv@JiMD8zWD4B@;SECURITY=SSL;
# 2020-03-30T09:55:32.413 iotfunctions.db.__init__ DEBUG Found database type in os variables: db2
# 2020-03-30T09:55:32.414 iotfunctions.db.__init__ INFO Connection string for SqlAlchemy => db2): db2+ibm_db://bluadmin:neCsbd2qUWygbymZv@JiMD8zWD4B@@db2w-ssctxwa.us-south.db2w.cloud.ibm.com:50001/BLUDB;SECURITY=SSL;
# 2020-03-30T09:55:32.415 iotfunctions.db.__init__ DEBUG created a CosClient object
# 2020-03-30T09:55:34.703 iotfunctions.db.__init__ DEBUG Db connection established
# 2020-03-30T09:55:36.245 iotfunctions.db.http_request DEBUG http request successful. status 200
# 2020-03-30T09:55:36.248 analytics_service.pmlib.pipeline._ModelPipelineConfig.__init__ DEBUG features=['rh', 'temp', 'pressure', 'flow', 'energy', 'vibration'], features_for_training=['installdate', 'faildate'], predictions=['predicted_time_to_failure'], features_resampled={}, inputs=['IIOT:rh', 'IIOT:temp', 'IIOT:pressure', 'IIOT:flow', 'IIOT:energy', 'IIOT:vibration', ':installdate', ':faildate'], renamed_inputs=['rh', 'temp', 'pressure', 'flow', 'energy', 'vibration', 'installdate', 'faildate']
# 2020-03-30T09:55:36.255 analytics_service.pmlib.pipeline._ModelPipelineConfig.__init__ DEBUG kwargs={}
# 2020-03-30T09:55:36.258 iotfunctions.metadata.__init__ DEBUG Initializing new entity type using iotfunctions 2.0.3
# 2020-03-30T09:55:36.271 iotfunctions.util.__init__ DEBUG Starting trace
# 2020-03-30T09:55:36.271 iotfunctions.util.__init__ DEBUG Trace name: auto_trace_1016_20200330095536
# 2020-03-30T09:55:36.275 iotfunctions.util.__init__ DEBUG auto_save None
# 2020-03-30T09:55:36.277 iotfunctions.metadata.__init__ WARNING No _db_schema specified in **kwargs. Usingdefault database schema.
# 2020-03-30T09:55:36.281 iotfunctions.util.categorize_args DEBUG categorizing arguments
# 2020-03-30T09:55:37.800 iotfunctions.metadata.__init__ DEBUG Initialized entity type
# _AssetGroupEntityType:apm_1016
# Functions:
# Granularities:
# No schedules metadata
# 2020-03-30T09:55:37.802 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.__init__ DEBUG loader_inputs=('IIOT:rh', 'IIOT:temp', 'IIOT:pressure', 'IIOT:flow', 'IIOT:energy', 'IIOT:vibration', ':installdate', ':faildate'), loader_names=('rh', 'temp', 'pressure', 'flow', 'energy', 'vibration', 'installdate', 'faildate')
# 2020-03-30T09:55:37.803 analytics_service.pmlib.loader.AssetLoader._validate_data_items DEBUG all_entity_types={'IOT', 'ZPMI', '1015', 'IIOT', 'ASSET_CACHE', '1011', '1016'}
# 2020-03-30T09:55:37.804 analytics_service.pmlib.loader.AssetLoader._set_asset_device_mappings INFO input_asset_device_mappings=None, asset_device_mappings={}, entity_type_meta={}
# 2020-03-30T09:55:37.805 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.__init__ DEBUG pipeline_config={'features': ['rh', 'temp', 'pressure', 'flow', 'energy', 'vibration'], 'inputs': ['IIOT:rh', 'IIOT:temp', 'IIOT:pressure', 'IIOT:flow', 'IIOT:energy', 'IIOT:vibration', ':installdate', ':faildate'], 'renamed_inputs': ['rh', 'temp', 'pressure', 'flow', 'energy', 'vibration', 'installdate', 'faildate'], 'features_for_training': ['installdate', 'faildate'], 'targets': ['installdate', 'faildate'], 'predictions': ['predicted_time_to_failure'], 'features_resampled': {}}
# 2020-03-30T09:55:37.807 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.__init__ DEBUG post_processing=[{'functionName': 'Maximum', 'enabled': True, 'granularity': 'Daily', 'output': {'name': 'daily_predicted_time_to_failure'}, 'input': {'source': 'predicted_time_to_failure'}}], incremental_summary=True

# %% [markdown]
# The example above configured a pipeline for this model, accepting **```p_episode```, ```t_episode```, ```f_episode```**, and **```c_episode```** of Watson IOT Platform device type **```SampleTimeToFailureSensor```**. It also uses asset attributes **```installdate```** and **```faildate```** to extract the labels for training. The predicted output of the trained model instance is called **```predicted_time_to_failure```**.

# %% [markdown]
# By default, this model also generated daily aggregated prediction result taking output names in the form of **```daily_<predicted_failure_date_output_name>```**.

# %% [markdown]
# <a id="train-model-instance"></a>
# ## Train the Model Instance
#
# With the model pipeline configured, now you can train the model instance:

# %%
df = group.execute()
# Out:
# 2020-03-30T09:55:37.817 analytics_service.pmlib.cache_loader.AssetCacheRefresher.execute INFO start_ts=None, end_ts=None, entities=None
# 2020-03-30T09:55:43.384 pmlib.util.api_request INFO method=get, url=https://api-us.connectedproducts.internetofthings.ibmcloud.com/api/meta/v1/CTP-PMI-Democore-31/entityType/ASSET_CACHE, headers={'Content-Type': 'application/json', 'X-api-key': '********', 'X-api-token': '********', 'Cache-Control': 'no-cache'}, timeout=30, ssl_verify=True, json=None, session=None, kwargs={}
# 2020-03-30T09:55:44.063 pmlib.util.api_request INFO resp.status_code=200, method=get, url=https://api-us.connectedproducts.internetofthings.ibmcloud.com/api/meta/v1/CTP-PMI-Democore-31/entityType/ASSET_CACHE
# 2020-03-30T09:55:44.065 iotfunctions.metadata.__init__ DEBUG Initializing new entity type using iotfunctions 2.0.3
# 2020-03-30T09:55:44.066 iotfunctions.util.__init__ DEBUG Starting trace
# 2020-03-30T09:55:44.067 iotfunctions.util.__init__ DEBUG Trace name: auto_trace_ASSET_CACHE_20200330095544
# 2020-03-30T09:55:44.068 iotfunctions.util.__init__ DEBUG auto_save None
# 2020-03-30T09:55:44.070 iotfunctions.metadata.__init__ WARNING No _db_schema specified in **kwargs. Usingdefault database schema.
# 2020-03-30T09:55:44.072 iotfunctions.util.categorize_args DEBUG categorizing arguments
# 2020-03-30T09:55:44.073 iotfunctions.metadata.__init__ DEBUG Initialized entity type
# EntityType:apm_asset_cache
# Functions:
# Granularities:
# No schedules metadata
# 2020-03-30T09:55:44.074 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/assetgroup/1016/devicemapping?instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json=None, session=None, kwargs={}
# 2020-03-30T09:55:45.469 pmlib.util.api_request INFO resp.status_code=200, method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/assetgroup/1016/devicemapping?instanceId=4ac3917e
# 2020-03-30T09:55:45.471 pmlib.api._refresh_asset_cache DEBUG raw_asset_device_mappings=[{'devices': ['IIOT:ZIOT1001'], 'assetNum': 'ZIOT1001', 'siteId': 'WCM'}, {'devices': ['IIOT:ZIOT1002'], 'assetNum': 'ZIOT1002', 'siteId': 'WCM'}, {'devices': ['IIOT:ZIOT1003'], 'assetNum': 'ZIOT1003', 'siteId': 'WCM'}, {'devices': ['IIOT:ZIOT1004'], 'assetNum': 'ZIOT1004', 'siteId': 'WCM'}, {'devices': ['IIOT:ZIOT1005'], 'assetNum': 'ZIOT1005', 'siteId': 'WCM'}]
# 2020-03-30T09:55:45.497 pmlib.api._refresh_asset_cache DEBUG df_asset_group_members=shape=(5, 4), index={0: 'int64'}, columns={'assetgroup': 'O', 'site': 'O', 'asset': 'O', 'assetid': 'O'}, head(5)=
#   assetgroup site     asset            assetid
# 0       1016  WCM  ZIOT1001  ZIOT1001-____-WCM
# 1       1016  WCM  ZIOT1002  ZIOT1002-____-WCM
# 2       1016  WCM  ZIOT1003  ZIOT1003-____-WCM
# 3       1016  WCM  ZIOT1004  ZIOT1004-____-WCM
# 4       1016  WCM  ZIOT1005  ZIOT1005-____-WCM
# 2020-03-30T09:55:45.504 pmlib.api._refresh_asset_cache DEBUG df_asset_device_mappings=shape=(5, 5), index={0: 'int64'}, columns={'site': 'O', 'asset': 'O', 'devicetype': 'O', 'deviceid': 'O', 'attribute': 'O'}, head(5)=
#   site     asset devicetype  deviceid attribute
# 0  WCM  ZIOT1001       IIOT  ZIOT1001
# 1  WCM  ZIOT1002       IIOT  ZIOT1002
# 2  WCM  ZIOT1003       IIOT  ZIOT1003
# 3  WCM  ZIOT1004       IIOT  ZIOT1004
# 4  WCM  ZIOT1005       IIOT  ZIOT1005
# 2020-03-30T09:55:48.211 iotfunctions.pipeline.execute DEBUG Executing pipeline with 2 stages.
# 2020-03-30T09:55:48.212 iotfunctions.pipeline.execute DEBUG No dataframe supplied for pipeline execution. Getting entity source data
# 2020-03-30T09:55:48.216 analytics_service.pmlib.loader.AssetLoader.execute INFO start_ts=None, end_ts=None, entities=None, df_input=None
# 2020-03-30T09:55:48.218 analytics_service.pmlib.loader.AssetLoader._load_asset_device_mappings DEBUG sql=SELECT apm_asset_groups.site, apm_asset_groups.asset, apm_asset_device_attributes.devicetype, apm_asset_device_attributes.deviceid
# FROM apm_asset_groups LEFT OUTER JOIN apm_asset_device_attributes ON apm_asset_device_attributes.site = apm_asset_groups.site AND apm_asset_device_attributes.asset = apm_asset_groups.asset
# WHERE apm_asset_groups.assetgroup = ?
# 2020-03-30T09:55:48.780 analytics_service.pmlib.loader.AssetLoader._load_asset_device_mappings DEBUG df_ahi_mappings=shape=(5, 5), index={0: 'int64'}, columns={'site': 'O', 'asset': 'O', 'devicetype': 'O', 'deviceid': 'O', 'assetfullid': 'O'}, head(5)=
#   site     asset devicetype  deviceid        assetfullid
# 0  WCM  ZIOT1001       IIOT  ZIOT1001  ZIOT1001-____-WCM
# 1  WCM  ZIOT1002       IIOT  ZIOT1002  ZIOT1002-____-WCM
# 2  WCM  ZIOT1003       IIOT  ZIOT1003  ZIOT1003-____-WCM
# 3  WCM  ZIOT1004       IIOT  ZIOT1004  ZIOT1004-____-WCM
# 4  WCM  ZIOT1005       IIOT  ZIOT1005  ZIOT1005-____-WCM
# 2020-03-30T09:55:48.791 analytics_service.pmlib.loader.AssetLoader._load_asset_device_mappings DEBUG sql=SELECT apm_asset_groups.site, apm_asset_groups.asset, apm_asset_devices.devicetype, apm_asset_devices.deviceid
# FROM apm_asset_groups LEFT OUTER JOIN apm_asset_devices ON apm_asset_devices.site = apm_asset_groups.site AND apm_asset_devices.asset = apm_asset_groups.asset
# WHERE apm_asset_groups.assetgroup = ?
# 2020-03-30T09:55:49.276 analytics_service.pmlib.loader.AssetLoader._load_asset_device_mappings DEBUG df_pmi_mappings=shape=(5, 5), index={0: 'int64'}, columns={'site': 'O', 'asset': 'O', 'devicetype': 'O', 'deviceid': 'O', 'assetfullid': 'O'}, head(5)=
#   site     asset devicetype deviceid        assetfullid
# 0  WCM  ZIOT1001       None     None  ZIOT1001-____-WCM
# 1  WCM  ZIOT1002       None     None  ZIOT1002-____-WCM
# 2  WCM  ZIOT1003       None     None  ZIOT1003-____-WCM
# 3  WCM  ZIOT1004       None     None  ZIOT1004-____-WCM
# 4  WCM  ZIOT1005       None     None  ZIOT1005-____-WCM
# 2020-03-30T09:55:49.280 analytics_service.pmlib.loader.AssetLoader._validate_mappings DEBUG asset_device_mappings={'ZIOT1001-____-WCM': ['IIOT:ZIOT1001'], 'ZIOT1002-____-WCM': ['IIOT:ZIOT1002'], 'ZIOT1003-____-WCM': ['IIOT:ZIOT1003'], 'ZIOT1004-____-WCM': ['IIOT:ZIOT1004'], 'ZIOT1005-____-WCM': ['IIOT:ZIOT1005']}
# 2020-03-30T09:55:49.281 analytics_service.pmlib.loader.AssetLoader._validate_mappings DEBUG features_meta={'IIOT': {'vibration', 'pressure', 'flow', 'energy', 'temp', 'rh'}, '': {'faildate', 'installdate'}}
# 2020-03-30T09:55:49.292 analytics_service.pmlib.loader.AssetLoader._validate_mappings DEBUG mappings_meta={'IIOT'}
# 2020-03-30T09:55:49.293 analytics_service.pmlib.loader.AssetLoader._set_asset_device_mappings INFO input_asset_device_mappings={'ZIOT1001-____-WCM': ['IIOT:ZIOT1001'], 'ZIOT1002-____-WCM': ['IIOT:ZIOT1002'], 'ZIOT1003-____-WCM': ['IIOT:ZIOT1003'], 'ZIOT1004-____-WCM': ['IIOT:ZIOT1004'], 'ZIOT1005-____-WCM': ['IIOT:ZIOT1005']}, asset_device_mappings={'ZIOT1001-____-WCM': ['IIOT:ZIOT1001'], 'ZIOT1002-____-WCM': ['IIOT:ZIOT1002'], 'ZIOT1003-____-WCM': ['IIOT:ZIOT1003'], 'ZIOT1004-____-WCM': ['IIOT:ZIOT1004'], 'ZIOT1005-____-WCM': ['IIOT:ZIOT1005']}, entity_type_meta={'IIOT': ['vibration', 'pressure', 'flow', 'energy', 'temp', 'rh'], '': ['faildate', 'installdate']}
# 2020-03-30T09:55:49.322 analytics_service.pmlib.loader.AssetLoader.execute DEBUG df_mappings=shape=(5, 3), index={0: 'int64'}, columns={'asset_id': 'O', 'entity_type': 'O', 'id': 'O'}, head(5)=
#             asset_id entity_type        id
# 0  ZIOT1001-____-WCM        IIOT  ZIOT1001
# 1  ZIOT1002-____-WCM        IIOT  ZIOT1002
# 2  ZIOT1003-____-WCM        IIOT  ZIOT1003
# 3  ZIOT1004-____-WCM        IIOT  ZIOT1004
# 4  ZIOT1005-____-WCM        IIOT  ZIOT1005
# 2020-03-30T09:55:49.331 analytics_service.pmlib.loader.AssetLoader.execute DEBUG entity_type=IIOT, data_items=['vibration', 'pressure', 'flow', 'energy', 'temp', 'rh'], is_asset_data=False
# 2020-03-30T09:55:49.331 iotfunctions.metadata.__init__ DEBUG Initializing new entity type using iotfunctions 2.0.3
# 2020-03-30T09:55:49.332 iotfunctions.util.__init__ DEBUG Starting trace
# 2020-03-30T09:55:49.332 iotfunctions.util.__init__ DEBUG Trace name: auto_trace_IIOT_20200330095549
# 2020-03-30T09:55:49.333 iotfunctions.util.__init__ DEBUG auto_save None
# 2020-03-30T09:55:49.334 iotfunctions.util.categorize_args DEBUG categorizing arguments
# 2020-03-30T09:55:50.743 iotfunctions.metadata.__init__ DEBUG Initialized entity type
# EntityType:iot_iiot
# Functions:
# Granularities:
# No schedules metadata
# 2020-03-30T09:55:50.744 analytics_service.pmlib.loader.AssetLoader.execute DEBUG before get_data: start_ts=None, end_ts=None, entity_type=IIOT, columns_to_load=['deviceid', 'rcv_timestamp_utc', 'vibration', 'pressure', 'flow', 'energy', 'temp', 'rh'], time_grain=None, agg_methods=None, agg_outputs=None
# 2020-03-30T09:55:50.746 pmlib.api._validate_resampling DEBUG time_grain=None, agg_methods={}, agg_outputs={}
# 2020-03-30T09:55:54.741 iotfunctions.metadata.index_df DEBUG Indexed dataframe on id, rcv_timestamp_utc
# 2020-03-30T09:55:54.758 pmlib.api.get_entity_type_data DEBUG df=shape=(11067, 8), index={'id': 'O', 'rcv_timestamp_utc': '<M8[ns]'}, columns={'deviceid': 'O', 'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', '_timestamp': '<M8[ns]'}, head(5)=
#                                   deviceid  vibration  pressure    flow  \
# id       rcv_timestamp_utc
# ZIOT1003 2020-03-26 10:07:32.517  ZIOT1003      0.083    1024.3  130.69
# ZIOT1001 2020-03-25 15:38:39.135  ZIOT1001      0.000    1024.7    1.78
#          2020-03-25 15:33:38.842  ZIOT1001      0.000    1024.7    1.76
#          2020-03-25 15:43:39.154  ZIOT1001      0.001    1024.7    1.83
#          2020-03-25 15:49:47.510  ZIOT1001      0.000    1024.7    1.79
#
#                                   energy  temp    rh              _timestamp
# id       rcv_timestamp_utc
# ZIOT1003 2020-03-26 10:07:32.517   15.94   7.0  35.0 2020-03-26 10:07:32.517
# ZIOT1001 2020-03-25 15:38:39.135    0.23  12.0  19.0 2020-03-25 15:38:39.135
#          2020-03-25 15:33:38.842    0.24  12.0  19.0 2020-03-25 15:33:38.842
#          2020-03-25 15:43:39.154    0.23  12.0  19.0 2020-03-25 15:43:39.154
#          2020-03-25 15:49:47.510    0.22  12.0  19.0 2020-03-25 15:49:47.510
# 2020-03-30T09:55:54.778 analytics_service.pmlib.loader.AssetLoader.execute DEBUG after get_data: df_loaded_IIOT=shape=(11067, 10), index={0: 'int64'}, columns={'id': 'O', 'rcv_timestamp_utc': '<M8[ns]', 'deviceid': 'O', 'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', '_timestamp': '<M8[ns]'}, head(5)=
#          id       rcv_timestamp_utc  deviceid  vibration  pressure    flow  \
# 0  ZIOT1003 2020-03-26 10:07:32.517  ZIOT1003      0.083    1024.3  130.69
# 1  ZIOT1001 2020-03-25 15:38:39.135  ZIOT1001      0.000    1024.7    1.78
# 2  ZIOT1001 2020-03-25 15:33:38.842  ZIOT1001      0.000    1024.7    1.76
# 3  ZIOT1001 2020-03-25 15:43:39.154  ZIOT1001      0.001    1024.7    1.83
# 4  ZIOT1001 2020-03-25 15:49:47.510  ZIOT1001      0.000    1024.7    1.79
#
#    energy  temp    rh              _timestamp
# 0   15.94   7.0  35.0 2020-03-26 10:07:32.517
# 1    0.23  12.0  19.0 2020-03-25 15:38:39.135
# 2    0.24  12.0  19.0 2020-03-25 15:33:38.842
# 3    0.23  12.0  19.0 2020-03-25 15:43:39.154
# 4    0.22  12.0  19.0 2020-03-25 15:49:47.510
# 2020-03-30T09:55:54.801 analytics_service.pmlib.loader.AssetLoader.execute DEBUG df_loaded_IIOT=shape=(11067, 10), index={0: 'int64'}, columns={'id': 'O', 'event_timestamp': '<M8[ns]', 'deviceid': 'O', 'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', '_timestamp': '<M8[ns]'}, head(5)=
#          id         event_timestamp  deviceid  vibration  pressure    flow  \
# 0  ZIOT1003 2020-03-26 10:07:32.517  ZIOT1003      0.083    1024.3  130.69
# 1  ZIOT1001 2020-03-25 15:38:39.135  ZIOT1001      0.000    1024.7    1.78
# 2  ZIOT1001 2020-03-25 15:33:38.842  ZIOT1001      0.000    1024.7    1.76
# 3  ZIOT1001 2020-03-25 15:43:39.154  ZIOT1001      0.001    1024.7    1.83
# 4  ZIOT1001 2020-03-25 15:49:47.510  ZIOT1001      0.000    1024.7    1.79
#
#    energy  temp    rh              _timestamp
# 0   15.94   7.0  35.0 2020-03-26 10:07:32.517
# 1    0.23  12.0  19.0 2020-03-25 15:38:39.135
# 2    0.24  12.0  19.0 2020-03-25 15:33:38.842
# 3    0.23  12.0  19.0 2020-03-25 15:43:39.154
# 4    0.22  12.0  19.0 2020-03-25 15:49:47.510
# 2020-03-30T09:55:54.835 analytics_service.pmlib.loader.AssetLoader.execute DEBUG df_loaded_n_mapped_IIOT=shape=(11067, 12), index={0: 'int64'}, columns={'id': 'O', 'event_timestamp': '<M8[ns]', 'deviceid': 'O', 'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', '_timestamp': '<M8[ns]', 'entity_type': 'O', 'asset_id': 'O'}, head(5)=
#          id         event_timestamp  deviceid  vibration  pressure    flow  \
# 0  ZIOT1003 2020-03-26 10:07:32.517  ZIOT1003      0.083    1024.3  130.69
# 1  ZIOT1003 2020-03-26 06:43:41.014  ZIOT1003      0.000    1023.8    1.81
# 2  ZIOT1003 2020-03-26 06:53:40.955  ZIOT1003      0.000    1023.8    1.79
# 3  ZIOT1003 2020-03-26 06:59:04.672  ZIOT1003      0.000    1023.8    1.77
# 4  ZIOT1003 2020-03-26 06:48:40.664  ZIOT1003      0.000    1023.8    1.80
#
#    energy  temp    rh              _timestamp entity_type           asset_id
# 0   15.94   7.0  35.0 2020-03-26 10:07:32.517        IIOT  ZIOT1003-____-WCM
# 1    0.24   1.0  52.0 2020-03-26 06:43:41.014        IIOT  ZIOT1003-____-WCM
# 2    0.24   1.0  52.0 2020-03-26 06:53:40.955        IIOT  ZIOT1003-____-WCM
# 3    0.22   1.0  52.0 2020-03-26 06:59:04.672        IIOT  ZIOT1003-____-WCM
# 4    0.21   1.0  52.0 2020-03-26 06:48:40.664        IIOT  ZIOT1003-____-WCM
# 2020-03-30T09:55:54.836 analytics_service.pmlib.loader.AssetLoader.execute DEBUG entity_type=, data_items=['faildate', 'installdate'], is_asset_data=True
# 2020-03-30T09:55:54.837 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/assetgroup/1016/devicemapping?instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json=None, session=None, kwargs={}
# 2020-03-30T09:55:56.222 pmlib.util.api_request INFO resp.status_code=200, method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/assetgroup/1016/devicemapping?instanceId=4ac3917e
# 2020-03-30T09:55:56.224 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/pmiboard/failurebyasset?assetNum=ZIOT1001&siteId=WCM&instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'assetNum': 'ZIOT1001', 'siteId': 'WCM'}, session=<requests_futures.sessions.FuturesSession object at 0x7fb72801f940>, kwargs={}
# 2020-03-30T09:55:56.228 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/pmiboard/failurebyasset?assetNum=ZIOT1002&siteId=WCM&instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'assetNum': 'ZIOT1002', 'siteId': 'WCM'}, session=<requests_futures.sessions.FuturesSession object at 0x7fb72801f940>, kwargs={}
# 2020-03-30T09:55:56.233 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/pmiboard/failurebyasset?assetNum=ZIOT1003&siteId=WCM&instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'assetNum': 'ZIOT1003', 'siteId': 'WCM'}, session=<requests_futures.sessions.FuturesSession object at 0x7fb72801f940>, kwargs={}
# 2020-03-30T09:55:56.236 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/pmiboard/failurebyasset?assetNum=ZIOT1004&siteId=WCM&instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'assetNum': 'ZIOT1004', 'siteId': 'WCM'}, session=<requests_futures.sessions.FuturesSession object at 0x7fb72801f940>, kwargs={}
# 2020-03-30T09:55:56.252 pmlib.util.api_request INFO method=get, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/pmiboard/failurebyasset?assetNum=ZIOT1005&siteId=WCM&instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'assetNum': 'ZIOT1005', 'siteId': 'WCM'}, session=<requests_futures.sessions.FuturesSession object at 0x7fb72801f940>, kwargs={}
# 2020-03-30T09:55:57.105 pmlib.api.get_asset_failure_history DEBUG response=<Response [200]>
# 2020-03-30T09:55:57.107 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-01-02T16:55:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'CIV', 'description': 'Problem WO with faildate for PMI', 'causecode': 'BREUK', 'remedycode': 'REPARAT', 'wonum': '1006'}
# 2020-03-30T09:55:57.132 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-01-09T16:55:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'CIV', 'description': 'Problem WO with faildate for PMI', 'causecode': 'MONTAGE', 'remedycode': 'VERVANG', 'wonum': '1007'}
# 2020-03-30T09:55:57.135 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-01-12T16:55:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'CIV', 'description': 'Problem WO with faildate for PMI', 'wonum': '1008'}
# 2020-03-30T09:55:57.137 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-01-14T08:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'CIV', 'description': 'Problem WO with faildate for PMI', 'wonum': '1009'}
# 2020-03-30T09:55:57.142 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-01-19T17:15:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'CIV', 'description': 'Problem WO with faildate for PMI', 'wonum': '1010'}
# 2020-03-30T09:55:57.143 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-27T15:11:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'CIV', 'description': 'WS-W1-6M Onderhoud Pompinstallatie', 'causecode': 'BREUK', 'remedycode': 'REPARAT', 'wonum': '1082'}
# 2020-03-30T09:55:57.145 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-07T12:02:11+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Fail date WO for PMI', 'causecode': 'BREUK', 'remedycode': 'VERVANG', 'wonum': '1001'}
# 2020-03-30T09:55:57.148 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-17T15:12:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'WS-E1-12M Onderhoud Pompinstallatie', 'causecode': 'BRAND', 'remedycode': 'VERVANG', 'wonum': '1084'}
# 2020-03-30T09:55:57.151 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-28T05:29:18+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Flow Failure', 'causecode': 'ONDERHD', 'remedycode': 'REPARAT', 'wonum': '1668'}
# 2020-03-30T09:55:57.156 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-20T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'WO for PMI Analysis', 'wonum': '1669'}
# 2020-03-30T09:55:57.158 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-22T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'WO for PMI Analysis', 'wonum': '1670'}
# 2020-03-30T09:55:57.159 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-30T08:33:07+02:00', 'classcode': 'PUMPS', 'problemcode': 'L-FLOW', 'description': 'Pump FLow too low', 'causecode': 'OUTLET', 'wonum': '1682'}
# 2020-03-30T09:55:57.164 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-26T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1671'}
# 2020-03-30T09:55:57.164 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-21T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1672'}
# 2020-03-30T09:55:57.165 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-25T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1673'}
# 2020-03-30T09:55:57.166 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-26T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1674'}
# 2020-03-30T09:55:57.171 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-27T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1675'}
# 2020-03-30T09:55:57.172 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-25T15:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1681'}
# 2020-03-30T09:55:57.173 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-25T15:13:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'PA', 'description': 'WS-E1-12M Onderhoud Elektromotor', 'causecode': 'FABRIEK', 'remedycode': 'VERVANG', 'wonum': '1086'}
# 2020-03-30T09:55:57.540 pmlib.api.get_asset_failure_history DEBUG response=<Response [200]>
# 2020-03-30T09:55:57.542 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-01-02T17:15:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'CIV', 'description': 'Problem WO with faildate for PMI', 'causecode': 'BRAND', 'remedycode': 'VERVANG', 'wonum': '1011'}
# 2020-03-30T09:55:57.543 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-07T12:02:11+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Fail date WO for PMI', 'causecode': 'MONTAGE', 'remedycode': 'REPARAT', 'wonum': '1002'}
# 2020-03-30T09:55:57.544 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-05T18:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'Problem WO with faildate for PMI', 'causecode': 'BREUK', 'remedycode': 'VERVANG', 'wonum': '1017'}
# 2020-03-30T09:55:57.544 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-20T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1676'}
# 2020-03-30T09:55:57.545 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-23T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1677'}
# 2020-03-30T09:55:57.546 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-24T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1678'}
# 2020-03-30T09:55:57.546 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-26T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1679'}
# 2020-03-30T09:55:57.547 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-27T12:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'WO for PMI Analysis', 'wonum': '1680'}
# 2020-03-30T09:55:57.551 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-07T12:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'PA', 'description': 'Problem WO with faildate for PMI', 'causecode': 'AFSTELFT', 'remedycode': 'REPARAT', 'wonum': '1012'}
# 2020-03-30T09:55:57.552 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-10T12:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'PA', 'description': 'Problem WO with faildate for PMI', 'causecode': 'MONTAGE', 'remedycode': 'VERVANG', 'wonum': '1013'}
# 2020-03-30T09:55:57.552 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-25T17:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'PA', 'description': 'Problem WO with faildate for PMI', 'causecode': 'BREUK', 'remedycode': 'VERVANG', 'wonum': '1014'}
# 2020-03-30T09:55:57.553 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-23T17:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'PA', 'description': 'Problem WO with faildate for PMI', 'causecode': 'FABRIEK', 'remedycode': 'REPARAT', 'wonum': '1015'}
# 2020-03-30T09:55:57.553 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-26T18:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'PA', 'description': 'Problem WO with faildate for PMI', 'causecode': 'ONDERHD', 'remedycode': 'FMECA', 'wonum': '1016'}
# 2020-03-30T09:55:57.554 pmlib.api.get_asset_failure_history DEBUG response=<Response [200]>
# 2020-03-30T09:55:57.555 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-07T12:02:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Fail date WO for PMI', 'causecode': 'ONDERHD', 'remedycode': 'UITVOER', 'wonum': '1003'}
# 2020-03-30T09:55:57.556 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-09T10:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'causecode': 'MONTAGE', 'remedycode': 'REPARAT', 'wonum': '1019'}
# 2020-03-30T09:55:57.571 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-11T12:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'causecode': 'BRAND', 'remedycode': 'REPARAT', 'wonum': '1020'}
# 2020-03-30T09:55:57.572 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-25T14:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'causecode': 'MONTAGE', 'remedycode': 'VERVANG', 'wonum': '1021'}
# 2020-03-30T09:55:57.572 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-26T14:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1022'}
# 2020-03-30T09:55:57.573 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-30T08:33:07+02:00', 'classcode': 'PUMPS', 'problemcode': 'L-FLOW', 'description': 'Pump FLow too low', 'causecode': 'INLET', 'remedycode': 'REPAIR', 'wonum': '1683'}
# 2020-03-30T09:55:57.574 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-27T11:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'Problem WO with faildate for PMI', 'causecode': 'AFSTELFT', 'remedycode': 'REPARAT', 'wonum': '1018'}
# 2020-03-30T09:55:57.575 pmlib.api.get_asset_failure_history DEBUG response=<Response [200]>
# 2020-03-30T09:55:57.575 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-03T14:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1023'}
# 2020-03-30T09:55:57.576 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-22T15:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1025'}
# 2020-03-30T09:55:57.591 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-25T17:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1026'}
# 2020-03-30T09:55:57.592 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-26T14:30:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1024'}
# 2020-03-30T09:55:57.593 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-27T12:02:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'Fail date WO for PMI', 'causecode': 'AFSTELFT', 'remedycode': 'REPARAT', 'wonum': '1004'}
# 2020-03-30T09:55:57.593 pmlib.api.get_asset_failure_history DEBUG response=<Response [200]>
# 2020-03-30T09:55:57.594 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-02T17:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1027'}
# 2020-03-30T09:55:57.595 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-04T19:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1028'}
# 2020-03-30T09:55:57.595 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-07T19:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1029'}
# 2020-03-30T09:55:57.611 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-11T19:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1030'}
# 2020-03-30T09:55:57.612 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-18T19:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1031'}
# 2020-03-30T09:55:57.612 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-25T19:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1032'}
# 2020-03-30T09:55:57.613 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-26T19:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1033'}
# 2020-03-30T09:55:57.614 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-27T11:00:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1034'}
# 2020-03-30T09:55:57.615 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-02-27T11:45:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'ELEK', 'description': 'Problem WO with faildate for PMI', 'wonum': '1035'}
# 2020-03-30T09:55:57.616 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-30T08:33:07+02:00', 'classcode': 'PUMPS', 'problemcode': 'L-FLOW', 'description': 'Pump FLow too low', 'causecode': 'LEAKAGE', 'remedycode': 'REPAIR', 'wonum': '1684'}
# 2020-03-30T09:55:57.616 pmlib.api.get_asset_failure_history DEBUG one_failure_history_record={'date': '2020-03-07T12:02:00+01:00', 'classcode': 'TOP-TECH', 'problemcode': 'MECH', 'description': 'Fail date WO for PMI', 'causecode': 'MONTAGE', 'remedycode': 'REPARAT', 'wonum': '1005'}
# 2020-03-30T09:55:57.979 analytics_service.pmlib.loader.AssetLoader.execute DEBUG df_loaded_asset_ts=shape=(55, 3), index={0: 'int64'}, columns={'asset_id': 'O', 'faildate': '<M8[ns]', 'event_timestamp': '<M8[ns]'}, head(5)=
#             asset_id            faildate     event_timestamp
# 0  ZIOT1001-____-WCM 2020-01-02 15:55:00 2020-01-02 15:55:00
# 1  ZIOT1001-____-WCM 2020-01-09 15:55:00 2020-01-09 15:55:00
# 2  ZIOT1001-____-WCM 2020-01-12 15:55:00 2020-01-12 15:55:00
# 3  ZIOT1001-____-WCM 2020-01-14 07:30:00 2020-01-14 07:30:00
# 4  ZIOT1001-____-WCM 2020-01-19 16:15:00 2020-01-19 16:15:00
# 2020-03-30T09:55:57.980 pmlib.util.api_request INFO method=post, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/pmiboard/assetmeta?instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'assets': [{'assetNum': 'ZIOT1001', 'siteId': 'WCM'}, {'assetNum': 'ZIOT1002', 'siteId': 'WCM'}, {'assetNum': 'ZIOT1003', 'siteId': 'WCM'}, {'assetNum': 'ZIOT1004', 'siteId': 'WCM'}, {'assetNum': 'ZIOT1005', 'siteId': 'WCM'}], 'attributes': ['faildate', 'installdate']}, session=None, kwargs={}
# 2020-03-30T09:55:59.357 pmlib.util.api_request INFO resp.status_code=200, method=post, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/pmiboard/assetmeta?instanceId=4ac3917e
# 2020-03-30T09:55:59.365 analytics_service.pmlib.loader.AssetLoader.execute DEBUG df_loaded_asset_dimension=shape=(5, 2), index={0: 'int64'}, columns={'asset_id': 'O', 'installdate': '<M8[ns]'}, head(5)=
#             asset_id installdate
# 0  ZIOT1001-____-WCM  2018-02-07
# 1  ZIOT1002-____-WCM  2018-02-07
# 2  ZIOT1003-____-WCM  2017-02-07
# 3  ZIOT1004-____-WCM  2017-02-07
# 4  ZIOT1005-____-WCM  2015-02-07
# 2020-03-30T09:55:59.374 analytics_service.pmlib.loader.AssetLoader.execute DEBUG df_loaded_n_mapped_=shape=(55, 3), index={0: 'int64'}, columns={'asset_id': 'O', 'faildate': '<M8[ns]', 'event_timestamp': '<M8[ns]'}, head(5)=
#             asset_id            faildate     event_timestamp
# 0  ZIOT1001-____-WCM 2020-01-02 15:55:00 2020-01-02 15:55:00
# 1  ZIOT1001-____-WCM 2020-01-09 15:55:00 2020-01-09 15:55:00
# 2  ZIOT1001-____-WCM 2020-01-12 15:55:00 2020-01-12 15:55:00
# 3  ZIOT1001-____-WCM 2020-01-14 07:30:00 2020-01-14 07:30:00
# 4  ZIOT1001-____-WCM 2020-01-19 16:15:00 2020-01-19 16:15:00
# 2020-03-30T09:55:59.377 analytics_service.pmlib.loader.AssetLoader.execute DEBUG before merge, df=None
# 2020-03-30T09:55:59.761 analytics_service.pmlib.loader.AssetLoader.execute DEBUG df_merged=shape=(11112, 11), index={'asset_id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'id': 'O', 'deviceid': 'O', 'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', '_timestamp': '<M8[ns]', 'entity_type': 'O', 'faildate': '<M8[ns]'}, df=
#                                                  id  deviceid  vibration  \
# asset_id          event_timestamp
# ZIOT1001-____-WCM 2020-01-02 15:55:00.000       NaN       NaN        NaN
#                   2020-01-09 15:55:00.000       NaN       NaN        NaN
#                   2020-01-12 15:55:00.000       NaN       NaN        NaN
#                   2020-01-14 07:30:00.000       NaN       NaN        NaN
#                   2020-01-19 16:15:00.000       NaN       NaN        NaN
#                   2020-02-07 11:02:11.000       NaN       NaN        NaN
#                   2020-02-20 11:00:00.000       NaN       NaN        NaN
#                   2020-02-22 11:00:00.000       NaN       NaN        NaN
#                   2020-02-25 14:00:00.000       NaN       NaN        NaN
#                   2020-02-25 15:08:38.819  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 15:12:41.015  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 15:13:39.080  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 15:18:40.767  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 15:23:39.000  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:26:07.190  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:33:38.842  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:38:39.135  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:43:39.154  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 15:48:39.135  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:49:47.510  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:49:48.668  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 15:49:49.892  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:53:38.957  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:56:25.354  ZIOT1001  ZIOT1001      0.000
#                   2020-02-25 15:58:39.018  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 16:03:39.841  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 16:07:41.172  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 16:07:42.220  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 16:07:43.551  ZIOT1001  ZIOT1001      1.000
#                   2020-02-25 16:08:39.461  ZIOT1001  ZIOT1001      0.000
# ...                                             ...       ...        ...
# ZIOT1005-____-WCM 2020-03-30 07:30:12.460  ZIOT1005  ZIOT1005      0.386
#                   2020-03-30 07:35:12.621  ZIOT1005  ZIOT1005      0.574
#                   2020-03-30 07:40:12.457  ZIOT1005  ZIOT1005      0.125
#                   2020-03-30 07:45:12.654  ZIOT1005  ZIOT1005      0.856
#                   2020-03-30 07:50:12.585  ZIOT1005  ZIOT1005      0.722
#                   2020-03-30 07:55:12.488  ZIOT1005  ZIOT1005      0.030
#                   2020-03-30 08:00:12.472  ZIOT1005  ZIOT1005      0.226
#                   2020-03-30 08:05:12.457  ZIOT1005  ZIOT1005      0.810
#                   2020-03-30 08:10:12.617  ZIOT1005  ZIOT1005      0.748
#                   2020-03-30 08:15:12.622  ZIOT1005  ZIOT1005      0.760
#                   2020-03-30 08:20:12.508  ZIOT1005  ZIOT1005      0.913
#                   2020-03-30 08:25:12.516  ZIOT1005  ZIOT1005      0.615
#                   2020-03-30 08:30:12.563  ZIOT1005  ZIOT1005      0.868
#                   2020-03-30 08:35:12.670  ZIOT1005  ZIOT1005      0.405
#                   2020-03-30 08:40:12.560  ZIOT1005  ZIOT1005      0.081
#                   2020-03-30 08:45:13.039  ZIOT1005  ZIOT1005      0.593
#                   2020-03-30 08:50:12.672  ZIOT1005  ZIOT1005      0.458
#                   2020-03-30 08:55:12.725  ZIOT1005  ZIOT1005      0.389
#                   2020-03-30 09:00:12.541  ZIOT1005  ZIOT1005      0.047
#                   2020-03-30 09:05:12.916  ZIOT1005  ZIOT1005      0.940
#                   2020-03-30 09:10:12.950  ZIOT1005  ZIOT1005      0.411
#                   2020-03-30 09:15:13.313  ZIOT1005  ZIOT1005      0.877
#                   2020-03-30 09:20:12.615  ZIOT1005  ZIOT1005      0.657
#                   2020-03-30 09:25:12.582  ZIOT1005  ZIOT1005      0.644
#                   2020-03-30 09:30:12.677  ZIOT1005  ZIOT1005      0.692
#                   2020-03-30 09:35:12.555  ZIOT1005  ZIOT1005      0.417
#                   2020-03-30 09:40:12.845  ZIOT1005  ZIOT1005      0.842
#                   2020-03-30 09:45:12.637  ZIOT1005  ZIOT1005      0.387
#                   2020-03-30 09:50:12.606  ZIOT1005  ZIOT1005      0.018
#                   2020-03-30 09:55:12.584  ZIOT1005  ZIOT1005      0.445
#
#                                            pressure    flow  energy  temp  \
# asset_id          event_timestamp
# ZIOT1001-____-WCM 2020-01-02 15:55:00.000       NaN     NaN     NaN   NaN
#                   2020-01-09 15:55:00.000       NaN     NaN     NaN   NaN
#                   2020-01-12 15:55:00.000       NaN     NaN     NaN   NaN
#                   2020-01-14 07:30:00.000       NaN     NaN     NaN   NaN
#                   2020-01-19 16:15:00.000       NaN     NaN     NaN   NaN
#                   2020-02-07 11:02:11.000       NaN     NaN     NaN   NaN
#                   2020-02-20 11:00:00.000       NaN     NaN     NaN   NaN
#                   2020-02-22 11:00:00.000       NaN     NaN     NaN   NaN
#                   2020-02-25 14:00:00.000       NaN     NaN     NaN   NaN
#                   2020-02-25 15:08:38.819   1025.49    1.81    0.23  12.0
#                   2020-02-25 15:12:41.015   1024.70    1.83    0.23  12.0
#                   2020-02-25 15:13:39.080   1024.70    1.84    0.23  12.0
#                   2020-02-25 15:18:40.767   1024.70    1.85    0.24  12.0
#                   2020-02-25 15:23:39.000   1024.70    1.80    0.22  12.0
#                   2020-02-25 15:26:07.190   1024.70    1.83    0.24  12.0
#                   2020-02-25 15:33:38.842   1024.70    1.76    0.24  12.0
#                   2020-02-25 15:38:39.135   1024.70    1.78    0.23  12.0
#                   2020-02-25 15:43:39.154   1024.70    1.83    0.23  12.0
#                   2020-02-25 15:48:39.135   1024.70    1.80    0.22  12.0
#                   2020-02-25 15:49:47.510   1024.70    1.79    0.22  12.0
#                   2020-02-25 15:49:48.668   1024.70    1.77    0.22  12.0
#                   2020-02-25 15:49:49.892   1024.70    1.77    0.22  12.0
#                   2020-02-25 15:53:38.957   1024.70    1.78    0.23  12.0
#                   2020-02-25 15:56:25.354   1024.70    1.79    0.22  12.0
#                   2020-02-25 15:58:39.018   1024.70    1.77    0.22  12.0
#                   2020-02-25 16:03:39.841   1024.70    1.78    0.25  12.0
#                   2020-02-25 16:07:41.172   1024.70    1.79    0.24  12.0
#                   2020-02-25 16:07:42.220   1024.70    1.80    0.23  12.0
#                   2020-02-25 16:07:43.551   1024.70    1.80    0.25  12.0
#                   2020-02-25 16:08:39.461   1024.70    1.82    0.23  12.0
# ...                                             ...     ...     ...   ...
# ZIOT1005-____-WCM 2020-03-30 07:30:12.460   1032.00  161.35   21.77   3.0
#                   2020-03-30 07:35:12.621   1032.00  104.50   11.62   3.0
#                   2020-03-30 07:40:12.457   1032.00    6.81   25.19   3.0
#                   2020-03-30 07:45:12.654   1032.00   61.36   11.81   3.0
#                   2020-03-30 07:50:12.585   1032.00   67.01   19.22   3.0
#                   2020-03-30 07:55:12.488   1032.00   69.84    1.96   3.0
#                   2020-03-30 08:00:12.472   1032.00   67.33    8.19   3.0
#                   2020-03-30 08:05:12.457   1032.00   27.45   30.51   3.0
#                   2020-03-30 08:10:12.617   1032.00  132.80    9.95   3.0
#                   2020-03-30 08:15:12.622   1032.00   69.58    3.10   3.0
#                   2020-03-30 08:20:12.508   1032.00   67.08   14.11   3.0
#                   2020-03-30 08:25:12.516   1032.00  157.22    4.69   3.0
#                   2020-03-30 08:30:12.563   1031.70  119.62   24.48   4.0
#                   2020-03-30 08:35:12.670   1031.70  157.63   23.20   4.0
#                   2020-03-30 08:40:12.560   1031.70   33.11   12.65   4.0
#                   2020-03-30 08:45:13.039   1031.70  177.37    5.87   4.0
#                   2020-03-30 08:50:12.672   1031.70  162.44   24.65   4.0
#                   2020-03-30 08:55:12.725   1031.70   66.38   23.80   4.0
#                   2020-03-30 09:00:12.541   1031.70   69.20   16.17   4.0
#                   2020-03-30 09:05:12.916   1031.70   75.99    9.60   4.0
#                   2020-03-30 09:10:12.950   1031.70  155.84   24.36   4.0
#                   2020-03-30 09:15:13.313   1031.30  169.24   10.19   6.0
#                   2020-03-30 09:20:12.615   1031.30   36.01   29.70   6.0
#                   2020-03-30 09:25:12.582   1031.30  147.86    8.90   6.0
#                   2020-03-30 09:30:12.677   1031.30   36.28    8.65   6.0
#                   2020-03-30 09:35:12.555   1031.30   30.67    8.08   6.0
#                   2020-03-30 09:40:12.845   1031.30   67.05   22.71   6.0
#                   2020-03-30 09:45:12.637   1031.30   19.48   12.73   6.0
#                   2020-03-30 09:50:12.606   1031.30   63.98    6.76   6.0
#                   2020-03-30 09:55:12.584   1031.30  165.00    9.78   6.0
#
#                                              rh              _timestamp  \
# asset_id          event_timestamp
# ZIOT1001-____-WCM 2020-01-02 15:55:00.000   NaN                     NaT
#                   2020-01-09 15:55:00.000   NaN                     NaT
#                   2020-01-12 15:55:00.000   NaN                     NaT
#                   2020-01-14 07:30:00.000   NaN                     NaT
#                   2020-01-19 16:15:00.000   NaN                     NaT
#                   2020-02-07 11:02:11.000   NaN                     NaT
#                   2020-02-20 11:00:00.000   NaN                     NaT
#                   2020-02-22 11:00:00.000   NaN                     NaT
#                   2020-02-25 14:00:00.000   NaN                     NaT
#                   2020-02-25 15:08:38.819  30.0 2020-02-25 15:08:38.819
#                   2020-02-25 15:12:41.015  19.0 2020-02-25 15:12:41.015
#                   2020-02-25 15:13:39.080  19.0 2020-02-25 15:13:39.080
#                   2020-02-25 15:18:40.767  19.0 2020-02-25 15:18:40.767
#                   2020-02-25 15:23:39.000  19.0 2020-02-25 15:23:39.000
#                   2020-02-25 15:26:07.190  19.0 2020-02-25 15:26:07.190
#                   2020-02-25 15:33:38.842  19.0 2020-02-25 15:33:38.842
#                   2020-02-25 15:38:39.135  19.0 2020-02-25 15:38:39.135
#                   2020-02-25 15:43:39.154  19.0 2020-02-25 15:43:39.154
#                   2020-02-25 15:48:39.135  19.0 2020-02-25 15:48:39.135
#                   2020-02-25 15:49:47.510  19.0 2020-02-25 15:49:47.510
#                   2020-02-25 15:49:48.668  19.0 2020-02-25 15:49:48.668
#                   2020-02-25 15:49:49.892  19.0 2020-02-25 15:49:49.892
#                   2020-02-25 15:53:38.957  19.0 2020-02-25 15:53:38.957
#                   2020-02-25 15:56:25.354  19.0 2020-02-25 15:56:25.354
#                   2020-02-25 15:58:39.018  19.0 2020-02-25 15:58:39.018
#                   2020-02-25 16:03:39.841  19.0 2020-02-25 16:03:39.841
#                   2020-02-25 16:07:41.172  19.0 2020-02-25 16:07:41.172
#                   2020-02-25 16:07:42.220  19.0 2020-02-25 16:07:42.220
#                   2020-02-25 16:07:43.551  19.0 2020-02-25 16:07:43.551
#                   2020-02-25 16:08:39.461  19.0 2020-02-25 16:08:39.461
# ...                                         ...                     ...
# ZIOT1005-____-WCM 2020-03-30 07:30:12.460  70.0 2020-03-30 07:30:12.460
#                   2020-03-30 07:35:12.621  70.0 2020-03-30 07:35:12.621
#                   2020-03-30 07:40:12.457  70.0 2020-03-30 07:40:12.457
#                   2020-03-30 07:45:12.654  70.0 2020-03-30 07:45:12.654
#                   2020-03-30 07:50:12.585  70.0 2020-03-30 07:50:12.585
#                   2020-03-30 07:55:12.488  70.0 2020-03-30 07:55:12.488
#                   2020-03-30 08:00:12.472  70.0 2020-03-30 08:00:12.472
#                   2020-03-30 08:05:12.457  70.0 2020-03-30 08:05:12.457
#                   2020-03-30 08:10:12.617  70.0 2020-03-30 08:10:12.617
#                   2020-03-30 08:15:12.622  70.0 2020-03-30 08:15:12.622
#                   2020-03-30 08:20:12.508  70.0 2020-03-30 08:20:12.508
#                   2020-03-30 08:25:12.516  70.0 2020-03-30 08:25:12.516
#                   2020-03-30 08:30:12.563  64.0 2020-03-30 08:30:12.563
#                   2020-03-30 08:35:12.670  64.0 2020-03-30 08:35:12.670
#                   2020-03-30 08:40:12.560  64.0 2020-03-30 08:40:12.560
#                   2020-03-30 08:45:13.039  64.0 2020-03-30 08:45:13.039
#                   2020-03-30 08:50:12.672  64.0 2020-03-30 08:50:12.672
#                   2020-03-30 08:55:12.725  64.0 2020-03-30 08:55:12.725
#                   2020-03-30 09:00:12.541  64.0 2020-03-30 09:00:12.541
#                   2020-03-30 09:05:12.916  64.0 2020-03-30 09:05:12.916
#                   2020-03-30 09:10:12.950  64.0 2020-03-30 09:10:12.950
#                   2020-03-30 09:15:13.313  65.0 2020-03-30 09:15:13.313
# ...
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819        1.0   1025.49  1.81    0.23
#                   2020-02-25 15:12:41.015        1.0   1024.70  1.83    0.23
#                   2020-02-25 15:13:39.080        1.0   1024.70  1.84    0.23
#                   2020-02-25 15:18:40.767        1.0   1024.70  1.85    0.24
#                   2020-02-25 15:23:39.000        0.0   1024.70  1.80    0.22
#
#                                            temp    rh faildate installdate
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819  12.0  30.0      NaT  2018-02-07
#                   2020-02-25 15:12:41.015  12.0  19.0      NaT  2018-02-07
#                   2020-02-25 15:13:39.080  12.0  19.0      NaT  2018-02-07
#                   2020-02-25 15:18:40.767  12.0  19.0      NaT  2018-02-07
#                   2020-02-25 15:23:39.000  12.0  19.0      NaT  2018-02-07
# 2020-03-30T09:56:00.278 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorFeatureExtraction.execute DEBUG df_duration_calculated=shape=(53, 14), index={0: 'int64'}, columns={'id': 'O', 'event_timestamp': '<M8[ns]', 'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', 'faildate': '<M8[ns]', 'installdate': '<M8[ns]', 'has_failed': 'int64', 'calc_date_end': '<M8[ns]', 'calc_date_start': '<M8[ns]', 'days_run': 'int64'}, head(5)=
#                     id         event_timestamp  vibration  pressure   flow  \
# 0    ZIOT1001-____-WCM 2020-02-25 15:08:38.819        1.0   1025.49   1.81
# 369  ZIOT1001-____-WCM 2020-02-26 11:00:00.000       19.0   1024.00  44.21
# 690  ZIOT1001-____-WCM 2020-02-27 14:11:00.000      352.0   1020.40  75.51
# 691  ZIOT1001-____-WCM 2020-03-17 14:12:00.000      352.0   1020.40  75.51
# 692  ZIOT1001-____-WCM 2020-03-21 11:00:00.000      352.0   1020.40  75.51
#
#      energy  temp    rh            faildate installdate  has_failed  \
# 0      0.23  12.0  30.0                 NaT  2018-02-07           0
# 369   13.04   8.0  33.0 2020-02-26 11:00:00  2018-02-07           1
# 690    7.65  13.0  41.0 2020-02-27 14:11:00  2018-02-07           1
# 691    7.65  13.0  41.0 2020-03-17 14:12:00  2018-02-07           1
# 692    7.65  13.0  41.0 2020-03-21 11:00:00  2018-02-07           1
#
#               calc_date_end         calc_date_start  days_run
# 0   2020-02-25 15:08:38.819 2018-02-07 00:00:00.000       748
# 369 2020-02-26 11:00:00.000 2020-02-25 15:08:38.819         0
# 690 2020-02-27 14:11:00.000 2020-02-26 11:00:00.000         1
# 691 2020-03-17 14:12:00.000 2020-02-27 14:11:00.000        19
# 692 2020-03-21 11:00:00.000 2020-03-17 14:12:00.000         3
# 2020-03-30T09:56:00.296 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorFeatureExtraction.execute DEBUG df_final=shape=(53, 10), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', 'faildate': '<M8[ns]', 'installdate': '<M8[ns]', 'has_failed': 'int64', 'days_run': 'int64'}, head(5)=
#                                            vibration  pressure   flow  energy  \
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819        1.0   1025.49   1.81    0.23
#                   2020-02-26 11:00:00.000       19.0   1024.00  44.21   13.04
#                   2020-02-27 14:11:00.000      352.0   1020.40  75.51    7.65
#                   2020-03-17 14:12:00.000      352.0   1020.40  75.51    7.65
#                   2020-03-21 11:00:00.000      352.0   1020.40  75.51    7.65
#
#                                            temp    rh            faildate  \
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819  12.0  30.0                 NaT
#                   2020-02-26 11:00:00.000   8.0  33.0 2020-02-26 11:00:00
#                   2020-02-27 14:11:00.000  13.0  41.0 2020-02-27 14:11:00
#                   2020-03-17 14:12:00.000  13.0  41.0 2020-03-17 14:12:00
#                   2020-03-21 11:00:00.000  13.0  41.0 2020-03-21 11:00:00
#
#                                           installdate  has_failed  days_run
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819  2018-02-07           0       748
#                   2020-02-26 11:00:00.000  2018-02-07           1         0
#                   2020-02-27 14:11:00.000  2018-02-07           1         1
#                   2020-03-17 14:12:00.000  2018-02-07           1        19
#                   2020-03-21 11:00:00.000  2018-02-07           1         3
# 2020-03-30T09:56:00.299 iotfunctions.pipeline._execute_stage DEBUG Function TimeToFailureEstimatorFeatureExtraction has no validate_df method. Skipping validation of the dataframe
# 2020-03-30T09:56:01.692 iotfunctions.metadata.register DEBUG found METRIC column deviceid
# 2020-03-30T09:56:01.694 iotfunctions.metadata.register DEBUG found METRIC column event_timestamp
# 2020-03-30T09:56:01.695 iotfunctions.metadata.register DEBUG found METRIC column devicetype
# 2020-03-30T09:56:01.695 iotfunctions.metadata.register DEBUG found METRIC column logicalinterface_id
# 2020-03-30T09:56:01.696 iotfunctions.metadata.register DEBUG found METRIC column eventtype
# 2020-03-30T09:56:01.697 iotfunctions.metadata.register DEBUG found METRIC column format
# 2020-03-30T09:56:01.698 iotfunctions.metadata.register DEBUG found METRIC column updated_utc
# 2020-03-30T09:56:02.413 iotfunctions.db.http_request DEBUG http request successful. status 200
# 2020-03-30T09:56:02.414 iotfunctions.metadata.register DEBUG Metadata registered for table apm_1016
# 2020-03-30T09:56:02.762 iotfunctions.pipeline.write WARNING Error while writing unmatched members to dimension. 'deviceid'
# 2020-03-30T09:56:02.764 iotfunctions.base.execute_preprocessing DEBUG Completed preprocessing
# 2020-03-30T09:56:02.780 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.execute DEBUG df_train=shape=(53, 8), index={0: 'int64'}, columns={'rh': 'float64', 'temp': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'vibration': 'float64', 'has_failed': 'int64', 'days_run': 'int64'}, head(5)=
#      rh  temp  pressure   flow  energy  vibration  has_failed  days_run
# 0  30.0  12.0   1025.49   1.81    0.23        1.0           0       748
# 1  33.0   8.0   1024.00  44.21   13.04       19.0           1         0
# 2  41.0  13.0   1020.40  75.51    7.65      352.0           1         1
# 3  41.0  13.0   1020.40  75.51    7.65      352.0           1        19
# 4  41.0  13.0   1020.40  75.51    7.65      352.0           1         3
# 2020-03-30T09:56:02.781 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.execute INFO training model None
# 2020-03-30T09:56:02.782 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.train_model INFO override_training_stages=None
# 2020-03-30T09:56:02.801 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.get_stages DEBUG event_column=has_failed, duration_column=days_run
# 2020-03-30T09:56:02.802 srom.pipeline.srom_pipeline.set_stages DEBUG total nodes 4
# 2020-03-30T09:56:02.806 srom.pipeline.execution_types.srom_single_node_search.srom_single_node_search DEBUG Reset n_jobs to more sane value of 1
# 2020-03-30T09:56:03.272 srom.pipeline.execution_types.srom_single_node_search.srom_single_node_search DEBUG Reset n_jobs to more sane value of 1
# 2020-03-30T09:56:05.518 srom.pipeline.execution_types.srom_single_node_search.srom_single_node_search DEBUG Reset n_jobs to more sane value of 1
# 2020-03-30T09:56:07.374 srom.pipeline.execution_types.srom_single_node_search.srom_single_node_search DEBUG Reset n_jobs to more sane value of 1
# 2020-03-30T09:56:08.690 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.save_model DEBUG saved apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168
# 2020-03-30T09:56:08.700 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.get_df_for_prediction DEBUG df_for_prediction=shape=(11100, 6), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'rh': 'float64', 'temp': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'vibration': 'float64'}, head(5)=
#                                              rh  temp  pressure  flow  energy  \
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819  30.0  12.0   1025.49  1.81    0.23
#                   2020-02-25 15:12:41.015  19.0  12.0   1024.70  1.83    0.23
#                   2020-02-25 15:13:39.080  19.0  12.0   1024.70  1.84    0.23
#                   2020-02-25 15:18:40.767  19.0  12.0   1024.70  1.85    0.24
#                   2020-02-25 15:23:39.000  19.0  12.0   1024.70  1.80    0.22
#
#                                            vibration
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819        1.0
#                   2020-02-25 15:12:41.015        1.0
#                   2020-02-25 15:13:39.080        1.0
#                   2020-02-25 15:18:40.767        1.0
#                   2020-02-25 15:23:39.000        0.0
# 2020-03-30T09:56:10.956 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.execute DEBUG df_prediction=shape=(11100, 1), index={0: 'int64'}, columns={0: 'float64'}, head(5)=
#              0
# 0  1358.667193
# 1   753.213066
# 2   753.167465
# 3   753.060735
# 4   753.571376
# 2020-03-30T09:56:10.958 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.process_prediction_result DEBUG prediction_result_length=11100, prediction_result=[[1358.6671928 ]
#  [ 753.21306576]
#  [ 753.1674648 ]
#  [ 753.06073486]
#  [ 753.5713757 ]
#  [ 753.31232707]
#  [ 753.63152028]
#  [ 753.60144806]
#  [ 753.21306576]
#  [ 753.5713757 ]]
# 2020-03-30T09:56:10.972 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.process_prediction_result DEBUG final_prediction_result_length=11100, final_prediction_result=[1358.6671928034116, 753.2130657628181, 753.1674648036277, 753.0607348561473, 753.5713757013701, 753.3123270748033, 753.6315202793752, 753.6014480585504, 753.2130657628181, 753.5713757013701]
# 2020-03-30T09:56:11.500 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.execute DEBUG df_final=shape=(11100, 9), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'vibration': 'float64', 'pressure': 'float64', 'flow': 'float64', 'energy': 'float64', 'temp': 'float64', 'rh': 'float64', 'faildate': '<M8[ns]', 'installdate': '<M8[ns]', 'predicted_time_to_failure': 'float64'}, head(5)=
#                                            vibration  pressure  flow  energy  \
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819        1.0   1025.49  1.81    0.23
#                   2020-02-25 15:12:41.015        1.0   1024.70  1.83    0.23
#                   2020-02-25 15:13:39.080        1.0   1024.70  1.84    0.23
#                   2020-02-25 15:18:40.767        1.0   1024.70  1.85    0.24
#                   2020-02-25 15:23:39.000        0.0   1024.70  1.80    0.22
#
#                                            temp    rh faildate installdate  \
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819  12.0  30.0      NaT  2018-02-07
#                   2020-02-25 15:12:41.015  12.0  19.0      NaT  2018-02-07
#                   2020-02-25 15:13:39.080  12.0  19.0      NaT  2018-02-07
#                   2020-02-25 15:18:40.767  12.0  19.0      NaT  2018-02-07
#                   2020-02-25 15:23:39.000  12.0  19.0      NaT  2018-02-07
#
#                                            predicted_time_to_failure
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819                1358.667193
#                   2020-02-25 15:12:41.015                 753.213066
#                   2020-02-25 15:13:39.080                 753.167465
#                   2020-02-25 15:18:40.767                 753.060735
#                   2020-02-25 15:23:39.000                 753.571376
# 2020-03-30T09:56:11.503 iotfunctions.pipeline._execute_stage DEBUG Function TimeToFailureEstimatorSrom has no validate_df method. Skipping validation of the dataframe
# 2020-03-30T09:56:11.864 iotfunctions.pipeline.write WARNING Error while writing unmatched members to dimension. 'deviceid'
# 2020-03-30T09:56:11.866 analytics_service.pmlib.pipeline._ModelPipelineConfig.__init__ DEBUG features=['rh', 'temp', 'pressure', 'flow', 'energy', 'vibration'], features_for_training=['installdate', 'faildate'], predictions=['predicted_time_to_failure'], features_resampled={}, inputs=['IIOT:rh', 'IIOT:temp', 'IIOT:pressure', 'IIOT:flow', 'IIOT:energy', 'IIOT:vibration'], renamed_inputs=['rh', 'temp', 'pressure', 'flow', 'energy', 'vibration']
# 2020-03-30T09:56:11.869 analytics_service.pmlib.pipeline._ModelPipelineConfig.__init__ DEBUG kwargs={}
# 2020-03-30T09:56:11.872 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.execute DEBUG adjusted after model trained: loader_inputs=('IIOT:rh', 'IIOT:temp', 'IIOT:pressure', 'IIOT:flow', 'IIOT:energy', 'IIOT:vibration'), loader_names=('rh', 'temp', 'pressure', 'flow', 'energy', 'vibration')
# 2020-03-30T09:56:11.875 analytics_service.pmlib.loader.AssetLoader._validate_mappings DEBUG asset_device_mappings={'ZIOT1001-____-WCM': ['IIOT:ZIOT1001'], 'ZIOT1002-____-WCM': ['IIOT:ZIOT1002'], 'ZIOT1003-____-WCM': ['IIOT:ZIOT1003'], 'ZIOT1004-____-WCM': ['IIOT:ZIOT1004'], 'ZIOT1005-____-WCM': ['IIOT:ZIOT1005']}
# 2020-03-30T09:56:11.877 analytics_service.pmlib.loader.AssetLoader._validate_mappings DEBUG features_meta={'IIOT': {'vibration', 'pressure', 'flow', 'energy', 'temp', 'rh'}}
# 2020-03-30T09:56:11.880 analytics_service.pmlib.loader.AssetLoader._validate_mappings DEBUG mappings_meta={'IIOT'}
# 2020-03-30T09:56:11.883 analytics_service.pmlib.loader.AssetLoader._set_asset_device_mappings INFO input_asset_device_mappings={'ZIOT1001-____-WCM': ['IIOT:ZIOT1001'], 'ZIOT1002-____-WCM': ['IIOT:ZIOT1002'], 'ZIOT1003-____-WCM': ['IIOT:ZIOT1003'], 'ZIOT1004-____-WCM': ['IIOT:ZIOT1004'], 'ZIOT1005-____-WCM': ['IIOT:ZIOT1005']}, asset_device_mappings={'ZIOT1001-____-WCM': ['IIOT:ZIOT1001'], 'ZIOT1002-____-WCM': ['IIOT:ZIOT1002'], 'ZIOT1003-____-WCM': ['IIOT:ZIOT1003'], 'ZIOT1004-____-WCM': ['IIOT:ZIOT1004'], 'ZIOT1005-____-WCM': ['IIOT:ZIOT1005']}, entity_type_meta={'IIOT': ['vibration', 'pressure', 'flow', 'energy', 'temp', 'rh']}
# 2020-03-30T09:56:11.886 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.execute DEBUG new_training=True, training_timestamp=1585562168
# 2020-03-30T09:56:11.888 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.execute DEBUG self.model_timestamp={'TimeToFailureEstimatorSrom': '1585562168'}
# 2020-03-30T09:56:11.906 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.execute DEBUG pipeline_final_df=shape=(11100, 1), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'predicted_time_to_failure': 'float64'}, head(5)=
#                                            predicted_time_to_failure
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819                1358.667193
#                   2020-02-25 15:12:41.015                 753.213066
#                   2020-02-25 15:13:39.080                 753.167465
#                   2020-02-25 15:18:40.767                 753.060735
#                   2020-02-25 15:23:39.000                 753.571376

# %% [markdown]
# Once this method completes successfully, you'll have a trained model instance reday (for next step, see below) and also with the prediction results returned as a dataframe for verification.

# %% [markdown]
# <a id="register-trained-model-instance"></a>
# ## Register the Trained Model Instance

# %% [markdown]
# If the trained model instance looks good, you can register it to Maximo APM PMI:

# %%
group.register()
# Out:
# 2020-03-30T09:56:11.915 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG target_pipeilne_class=pmlib.time_to_failure.TimeToFailureAssetGroupPipeline, url=None
# 2020-03-30T09:56:11.921 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG catalog_config={'name': 'TimeToFailureAssetGroupPipeline', 'description': 'TimeToFailureAssetGroupPipeline', 'moduleAndTargetName': 'pmlib.time_to_failure.TimeToFailureAssetGroupPipeline', 'url': 'https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/4ac3917e/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/lib/download?filename=pmlib-1.0.0.tar.gz', 'category': 'TRANSFORMER', 'tags': [], 'output': [{'name': 'names', 'description': 'Provide a list of output names to be generated from the pipeline.', 'dataType': 'ARRAY', 'jsonSchema': {'minItems': 1, '$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'array', 'items': {'type': 'string'}}, 'tags': []}], 'input': [{'name': 'asset_group_id', 'type': 'CONSTANT', 'required': True, 'dataType': 'LITERAL'}, {'name': 'model_pipeline', 'type': 'CONSTANT', 'required': True, 'dataType': 'JSON'}, {'name': 'fillna', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL', 'values': ['backfill', 'bfill', 'ffill', 'pad']}, {'name': 'fillna_exclude', 'type': 'CONSTANT', 'required': False, 'dataType': 'ARRAY', 'dataTypeForArray': ['LITERAL'], 'jsonSchema': {'minItems': 1, '$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'array', 'items': {'type': 'string'}}}, {'name': 'dropna', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL', 'values': ['any', 'all']}, {'name': 'dropna_exclude', 'type': 'CONSTANT', 'required': False, 'dataType': 'ARRAY', 'dataTypeForArray': ['LITERAL'], 'jsonSchema': {'minItems': 1, '$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'array', 'items': {'type': 'string'}}}, {'name': 'asset_device_mappings', 'type': 'CONSTANT', 'required': False, 'dataType': 'JSON'}, {'name': 'model_timestamp', 'type': 'CONSTANT', 'required': False, 'dataType': 'JSON'}, {'name': 'local_model', 'type': 'CONSTANT', 'required': False, 'dataType': 'BOOLEAN'}, {'name': 'apm_id', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL'}, {'name': 'apm_api_baseurl', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL'}, {'name': 'apm_api_baseurl', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL'}]}
# 2020-03-30T09:56:11.928 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG model_template_body={"modelTemplateId": "TimeToFailureAssetGroupPipeline", "modelTemplateName": "Predicted Failure Date", "modelTemplateDesc": "Predicted Failure Date", "modelJson": {"name": "TimeToFailureAssetGroupPipeline", "description": "TimeToFailureAssetGroupPipeline", "moduleAndTargetName": "pmlib.time_to_failure.TimeToFailureAssetGroupPipeline", "url": "https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/4ac3917e/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/lib/download?filename=pmlib-1.0.0.tar.gz", "category": "TRANSFORMER", "tags": [], "output": [{"name": "names", "description": "Provide a list of output names to be generated from the pipeline.", "dataType": "ARRAY", "jsonSchema": {"minItems": 1, "$schema": "http://json-schema.org/draft-07/schema#", "type": "array", "items": {"type": "string"}}, "tags": []}], "input": [{"name": "asset_group_id", "type": "CONSTANT", "required": true, "dataType": "LITERAL"}, {"name": "model_pipeline", "type": "CONSTANT", "required": true, "dataType": "JSON"}, {"name": "fillna", "type": "CONSTANT", "required": false, "dataType": "LITERAL", "values": ["backfill", "bfill", "ffill", "pad"]}, {"name": "fillna_exclude", "type": "CONSTANT", "required": false, "dataType": "ARRAY", "dataTypeForArray": ["LITERAL"], "jsonSchema": {"minItems": 1, "$schema": "http://json-schema.org/draft-07/schema#", "type": "array", "items": {"type": "string"}}}, {"name": "dropna", "type": "CONSTANT", "required": false, "dataType": "LITERAL", "values": ["any", "all"]}, {"name": "dropna_exclude", "type": "CONSTANT", "required": false, "dataType": "ARRAY", "dataTypeForArray": ["LITERAL"], "jsonSchema": {"minItems": 1, "$schema": "http://json-schema.org/draft-07/schema#", "type": "array", "items": {"type": "string"}}}, {"name": "asset_device_mappings", "type": "CONSTANT", "required": false, "dataType": "JSON"}, {"name": "model_timestamp", "type": "CONSTANT", "required": false, "dataType": "JSON"}, {"name": "local_model", "type": "CONSTANT", "required": false, "dataType": "BOOLEAN"}, {"name": "apm_id", "type": "CONSTANT", "required": false, "dataType": "LITERAL"}, {"name": "apm_api_baseurl", "type": "CONSTANT", "required": false, "dataType": "LITERAL"}, {"name": "apm_api_baseurl", "type": "CONSTANT", "required": false, "dataType": "LITERAL"}]}}
# 2020-03-30T09:56:11.931 pmlib.util.api_request INFO method=post, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/template?instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'modelTemplateId': 'TimeToFailureAssetGroupPipeline', 'modelTemplateName': 'Predicted Failure Date', 'modelTemplateDesc': 'Predicted Failure Date', 'modelJson': {'name': 'TimeToFailureAssetGroupPipeline', 'description': 'TimeToFailureAssetGroupPipeline', 'moduleAndTargetName': 'pmlib.time_to_failure.TimeToFailureAssetGroupPipeline', 'url': 'https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/4ac3917e/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/lib/download?filename=pmlib-1.0.0.tar.gz', 'category': 'TRANSFORMER', 'tags': [], 'output': [{'name': 'names', 'description': 'Provide a list of output names to be generated from the pipeline.', 'dataType': 'ARRAY', 'jsonSchema': {'minItems': 1, '$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'array', 'items': {'type': 'string'}}, 'tags': []}], 'input': [{'name': 'asset_group_id', 'type': 'CONSTANT', 'required': True, 'dataType': 'LITERAL'}, {'name': 'model_pipeline', 'type': 'CONSTANT', 'required': True, 'dataType': 'JSON'}, {'name': 'fillna', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL', 'values': ['backfill', 'bfill', 'ffill', 'pad']}, {'name': 'fillna_exclude', 'type': 'CONSTANT', 'required': False, 'dataType': 'ARRAY', 'dataTypeForArray': ['LITERAL'], 'jsonSchema': {'minItems': 1, '$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'array', 'items': {'type': 'string'}}}, {'name': 'dropna', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL', 'values': ['any', 'all']}, {'name': 'dropna_exclude', 'type': 'CONSTANT', 'required': False, 'dataType': 'ARRAY', 'dataTypeForArray': ['LITERAL'], 'jsonSchema': {'minItems': 1, '$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'array', 'items': {'type': 'string'}}}, {'name': 'asset_device_mappings', 'type': 'CONSTANT', 'required': False, 'dataType': 'JSON'}, {'name': 'model_timestamp', 'type': 'CONSTANT', 'required': False, 'dataType': 'JSON'}, {'name': 'local_model', 'type': 'CONSTANT', 'required': False, 'dataType': 'BOOLEAN'}, {'name': 'apm_id', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL'}, {'name': 'apm_api_baseurl', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL'}, {'name': 'apm_api_baseurl', 'type': 'CONSTANT', 'required': False, 'dataType': 'LITERAL'}]}}, session=None, kwargs={}
# 2020-03-30T09:56:13.848 pmlib.util.api_request INFO resp.status_code=200, method=post, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/template?instanceId=4ac3917e
# 2020-03-30T09:56:13.849 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG <Response [200]>
# 2020-03-30T09:56:13.853 iotfunctions.metadata.register DEBUG found METRIC column deviceid
# 2020-03-30T09:56:13.856 iotfunctions.metadata.register DEBUG found METRIC column event_timestamp
# 2020-03-30T09:56:13.859 iotfunctions.metadata.register DEBUG found METRIC column devicetype
# 2020-03-30T09:56:13.861 iotfunctions.metadata.register DEBUG found METRIC column logicalinterface_id
# 2020-03-30T09:56:13.865 iotfunctions.metadata.register DEBUG found METRIC column eventtype
# 2020-03-30T09:56:13.865 iotfunctions.metadata.register DEBUG found METRIC column format
# 2020-03-30T09:56:13.870 iotfunctions.metadata.register DEBUG found METRIC column updated_utc
# 2020-03-30T09:56:14.475 iotfunctions.db.http_request DEBUG http request successful. status 200
# 2020-03-30T09:56:14.477 iotfunctions.metadata.register DEBUG Metadata registered for table apm_1016
# 2020-03-30T09:56:15.269 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.save_model DEBUG saved apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168
# 2020-03-30T09:56:16.383 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.save_model DEBUG saved apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168_input.gz
# 2020-03-30T09:56:17.220 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.save_model DEBUG saved apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168_input_after_train_preprocess.gz
# 2020-03-30T09:56:18.058 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.save_model DEBUG saved apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168_to_train.gz
# 2020-03-30T09:56:19.181 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.save_model DEBUG saved apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168_to_predict.gz
# 2020-03-30T09:56:20.526 analytics_service.pmlib.time_to_failure.TimeToFailureEstimatorSrom.save_model DEBUG saved apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168_output.gz
# 2020-03-30T09:56:20.527 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG uploaded_models={'TimeToFailureEstimatorSrom': ['apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168']}
# 2020-03-30T09:56:20.530 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG model_output_dtypes={'predicted_time_to_failure': dtype('float64')}
# 2020-03-30T09:56:20.533 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG out=predicted_time_to_failure, model_output_dtypes[out]=float64, is_string_dtype=False, is_bool_dtype=False, is_datetime64_any_dtype=False, is_numeric_dtype=True
# 2020-03-30T09:56:20.535 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG kpi_config={'functionName': 'TimeToFailureAssetGroupPipeline', 'enabled': False, 'input': {'asset_group_id': '1016', 'model_pipeline': {'features': ['IIOT:rh', 'IIOT:temp', 'IIOT:pressure', 'IIOT:flow', 'IIOT:energy', 'IIOT:vibration'], 'features_for_training': [':installdate', ':faildate'], 'predictions': ['predicted_time_to_failure']}, 'incremental_summary': True, 'fillna': 'ffill', 'fillna_exclude': None, 'dropna': 'any', 'dropna_exclude': None, 'local_model': False, 'model_timestamp': {'TimeToFailureEstimatorSrom': '1585562168'}}, 'output': {'names': ['predicted_time_to_failure']}, 'outputMeta': {'predicted_time_to_failure': {'dataType': 'NUMBER'}}, 'backtrack': {'days': 0}}
# 2020-03-30T09:56:20.536 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG model_instance_body={"modelTemplateId": "TimeToFailureAssetGroupPipeline", "modelCosPath": {"TimeToFailureEstimatorSrom": ["apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168"]}, "instanceName": "1016_TimeToFailureAssetGroupPipeline_2020-03-30T09:56:20.536522", "instanceDesc": "1016_TimeToFailureAssetGroupPipeline_2020-03-30T09:56:20.536522", "kpiConfig": {"functionName": "TimeToFailureAssetGroupPipeline", "enabled": false, "input": {"asset_group_id": "1016", "model_pipeline": {"features": ["IIOT:rh", "IIOT:temp", "IIOT:pressure", "IIOT:flow", "IIOT:energy", "IIOT:vibration"], "features_for_training": [":installdate", ":faildate"], "predictions": ["predicted_time_to_failure"]}, "incremental_summary": true, "fillna": "ffill", "fillna_exclude": null, "dropna": "any", "dropna_exclude": null, "local_model": false, "model_timestamp": {"TimeToFailureEstimatorSrom": "1585562168"}}, "output": {"names": ["predicted_time_to_failure"]}, "outputMeta": {"predicted_time_to_failure": {"dataType": "NUMBER"}}, "backtrack": {"days": 0}}, "granularity": [{"name": "GroupDaily", "description": "GroupDaily", "frequency": "Daily", "dataItems": [], "entityFirst": false}, {"name": "Hourly", "description": "Hourly", "frequency": "Hourly", "dataItems": [], "entityFirst": true}, {"name": "GroupHourly", "description": "GroupHourly", "frequency": "Hourly", "dataItems": [], "entityFirst": false}, {"name": "Weekly", "description": "Weekly", "frequency": "Weekly", "dataItems": [], "entityFirst": true}, {"name": "GroupWeekly", "description": "GroupWeekly", "frequency": "Weekly", "dataItems": [], "entityFirst": false}, {"name": "Monthly", "description": "Monthly", "frequency": "Monthly", "dataItems": [], "entityFirst": true}, {"name": "GroupMonthly", "description": "GroupMonthly", "frequency": "Monthly", "dataItems": [], "entityFirst": false}], "postProcessing": [{"functionName": "Maximum", "enabled": true, "granularity": "Daily", "output": {"name": "daily_predicted_time_to_failure"}, "input": {"source": "predicted_time_to_failure"}, "backtrack": {"days": 0}}]}
# 2020-03-30T09:56:20.539 pmlib.util.api_request INFO method=post, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/1016/model?instanceId=4ac3917e, headers={'apmapitoken': '********'}, timeout=30, ssl_verify=True, json={'modelTemplateId': 'TimeToFailureAssetGroupPipeline', 'modelCosPath': {'TimeToFailureEstimatorSrom': ['apm/pmi/model/1016/TimeToFailureEstimatorSrom/predicted_time_to_failure_1585562168']}, 'instanceName': '1016_TimeToFailureAssetGroupPipeline_2020-03-30T09:56:20.536522', 'instanceDesc': '1016_TimeToFailureAssetGroupPipeline_2020-03-30T09:56:20.536522', 'kpiConfig': {'functionName': 'TimeToFailureAssetGroupPipeline', 'enabled': False, 'input': {'asset_group_id': '1016', 'model_pipeline': {'features': ['IIOT:rh', 'IIOT:temp', 'IIOT:pressure', 'IIOT:flow', 'IIOT:energy', 'IIOT:vibration'], 'features_for_training': [':installdate', ':faildate'], 'predictions': ['predicted_time_to_failure']}, 'incremental_summary': True, 'fillna': 'ffill', 'fillna_exclude': None, 'dropna': 'any', 'dropna_exclude': None, 'local_model': False, 'model_timestamp': {'TimeToFailureEstimatorSrom': '1585562168'}}, 'output': {'names': ['predicted_time_to_failure']}, 'outputMeta': {'predicted_time_to_failure': {'dataType': 'NUMBER'}}, 'backtrack': {'days': 0}}, 'granularity': [{'name': 'GroupDaily', 'description': 'GroupDaily', 'frequency': 'Daily', 'dataItems': [], 'entityFirst': False}, {'name': 'Hourly', 'description': 'Hourly', 'frequency': 'Hourly', 'dataItems': [], 'entityFirst': True}, {'name': 'GroupHourly', 'description': 'GroupHourly', 'frequency': 'Hourly', 'dataItems': [], 'entityFirst': False}, {'name': 'Weekly', 'description': 'Weekly', 'frequency': 'Weekly', 'dataItems': [], 'entityFirst': True}, {'name': 'GroupWeekly', 'description': 'GroupWeekly', 'frequency': 'Weekly', 'dataItems': [], 'entityFirst': False}, {'name': 'Monthly', 'description': 'Monthly', 'frequency': 'Monthly', 'dataItems': [], 'entityFirst': True}, {'name': 'GroupMonthly', 'description': 'GroupMonthly', 'frequency': 'Monthly', 'dataItems': [], 'entityFirst': False}], 'postProcessing': [{'functionName': 'Maximum', 'enabled': True, 'granularity': 'Daily', 'output': {'name': 'daily_predicted_time_to_failure'}, 'input': {'source': 'predicted_time_to_failure'}, 'backtrack': {'days': 0}}]}, session=None, kwargs={}
# 2020-03-30T09:56:22.339 pmlib.util.api_request INFO resp.status_code=200, method=post, url=https://prod.pmi.apm.maximo.ibm.com/ibm/pmi/service/rest/ds/dp7opk78635sbf809f07o4t53lum3c9eoaovpk9f/1016/model?instanceId=4ac3917e
# 2020-03-30T09:56:22.341 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG <Response [200]>
# 2020-03-30T09:56:22.345 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline.register DEBUG model_instance_response={'modelInstanceId': 'D17CE664-6651-49DF-94C5-C584D8B87E62', 'message': 'APM-PMI-I-0005: Created', 'status': 0}
# 2020-03-30T09:56:22.897 iotfunctions.db.http_request DEBUG http request successful. status 200
# 2020-03-30T09:56:22.902 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._write INFO granularities={'Daily': <iotfunctions.metadata.Granularity object at 0x7fb727fee4a8>, 'GroupDaily': <iotfunctions.metadata.Granularity object at 0x7fb6c410dac8>, 'Hourly': <iotfunctions.metadata.Granularity object at 0x7fb6c410dd30>, 'GroupHourly': <iotfunctions.metadata.Granularity object at 0x7fb6c410de10>, 'Weekly': <iotfunctions.metadata.Granularity object at 0x7fb6c410d2e8>, 'GroupWeekly': <iotfunctions.metadata.Granularity object at 0x7fb6c410d898>, 'Monthly': <iotfunctions.metadata.Granularity object at 0x7fb6c410d198>, 'GroupMonthly': <iotfunctions.metadata.Granularity object at 0x7fb6c410d390>}
# 2020-03-30T09:56:22.904 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._parse_kpi_dependency_tree DEBUG raw_metrics_set={'predicted_time_to_failure'}, derived_metrics_set=set()
# 2020-03-30T09:56:22.904 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._parse_kpi_dependency_tree DEBUG kpi_raw_sources={'predicted_time_to_failure'}, kpi_derived_sources=set(), kpi={'functionName': 'Maximum', 'enabled': True, 'granularity': 'Daily', 'output': {'name': 'daily_predicted_time_to_failure'}, 'input': {'source': 'predicted_time_to_failure'}, 'backtrack': {'days': 0}}
# 2020-03-30T09:56:22.909 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._write INFO processing_queue=[(1) daily_predicted_time_to_failure <- ['(0) predicted_time_to_failure']]
# 2020-03-30T09:56:22.912 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._write DEBUG grain_grouped_aggregators=OrderedDict([('Daily', [{'functionName': 'Maximum', 'enabled': True, 'granularity': 'Daily', 'output': {'name': 'daily_predicted_time_to_failure'}, 'input': {'source': 'predicted_time_to_failure'}, 'backtrack': {'days': 0}}])])
# 2020-03-30T09:56:22.914 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._write DEBUG aggregation_column_methods={'predicted_time_to_failure': ['max']}
# 2020-03-30T09:56:22.942 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._write DEBUG aggregation_after_groupby_df_grain=shape=(62, 1), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={('predicted_time_to_failure', 'max'): 'float64'}, head(5)=
#                                   predicted_time_to_failure
#                                                         max
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25                    1358.667193
#                   2020-02-26                      76.159989
#                   2020-02-27                     405.344200
#                   2020-03-17                     168.303605
#                   2020-03-21                     168.303605
# 2020-03-30T09:56:22.944 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._write INFO renamed_colsi={'predicted_time_to_failure|max': 'daily_predicted_time_to_failure'}
# 2020-03-30T09:56:22.952 analytics_service.pmlib.time_to_failure.TimeToFailureAssetGroupPipeline._write DEBUG aggregation_df_grain=
# shape=(62, 1), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'daily_predicted_time_to_failure': 'float64'}, head(5)=
#                                    daily_predicted_time_to_failure
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25                           1358.667193
#                   2020-02-26                             76.159989
#                   2020-02-27                            405.344200
#                   2020-03-17                            168.303605
#                   2020-03-21                            168.303605
# 2020-03-30T09:56:22.953 analytics_service.pmlib.persist.PersistColumns.__init__ DEBUG target_grain=None, target_grain_tuple=('', None, True), target_table=dm_1016
# 2020-03-30T09:56:22.960 analytics_service.pmlib.persist.PersistColumns.execute DEBUG df_input=shape=(11100, 1), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'predicted_time_to_failure': 'float64'}, head(5)=
#                                            predicted_time_to_failure
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819                1358.667193
#                   2020-02-25 15:12:41.015                 753.213066
#                   2020-02-25 15:13:39.080                 753.167465
#                   2020-02-25 15:18:40.767                 753.060735
#                   2020-02-25 15:23:39.000                 753.571376
# 2020-03-30T09:56:22.974 analytics_service.pmlib.persist.PersistColumns.execute DEBUG columns_to_persist=[('value_n', 'predicted_time_to_failure')]
# 2020-03-30T09:56:22.990 analytics_service.pmlib.persist.PersistColumns.execute DEBUG df_stacked=shape=(11100, 1), index={'id': 'O', 'event_timestamp': '<M8[ns]', 2: 'O'}, columns={'value_n': 'float64'}, head(5)=
#                                                                          value_n
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25 15:08:38.819 predicted_time_to_failure  1358.667193
#                   2020-02-25 15:12:41.015 predicted_time_to_failure   753.213066
#                   2020-02-25 15:13:39.080 predicted_time_to_failure   753.167465
#                   2020-02-25 15:18:40.767 predicted_time_to_failure   753.060735
#                   2020-02-25 15:23:39.000 predicted_time_to_failure   753.571376
# 2020-03-30T09:56:23.011 analytics_service.pmlib.persist.PersistColumns.execute DEBUG target_table=dm_1016, df_to_write=shape=(11100, 5), index={0: 'int64'}, columns={'entity_id': 'O', 'timestamp': '<M8[ns]', 'key': 'O', 'value_n': 'float64', 'last_update': '<M8[ns]'}, head(5)=
#            entity_id               timestamp                        key  \
# 0  ZIOT1001-____-WCM 2020-02-25 15:08:38.819  predicted_time_to_failure
# 1  ZIOT1001-____-WCM 2020-02-25 15:12:41.015  predicted_time_to_failure
# 2  ZIOT1001-____-WCM 2020-02-25 15:13:39.080  predicted_time_to_failure
# 3  ZIOT1001-____-WCM 2020-02-25 15:18:40.767  predicted_time_to_failure
# 4  ZIOT1001-____-WCM 2020-02-25 15:23:39.000  predicted_time_to_failure
#
#        value_n                last_update
# 0  1358.667193 2020-03-30 09:56:23.003802
# 1   753.213066 2020-03-30 09:56:23.003802
# 2   753.167465 2020-03-30 09:56:23.003802
# 3   753.060735 2020-03-30 09:56:23.003802
# 4   753.571376 2020-03-30 09:56:23.003802
# 2020-03-30T09:56:24.400 analytics_service.pmlib.persist.PersistColumns.execute DEBUG clearing existing data of kpi=predicted_time_to_failure
# 2020-03-30T09:56:24.874 pmlib.api._write_dataframe DEBUG df_before_tosql=shape=(11100, 5), index={0: 'int64'}, columns={'entity_id': 'O', 'KEY': 'O', 'TIMESTAMP': '<M8[ns]', 'last_update': '<M8[ns]', 'value_n': 'float64'}, head(5)=
#            entity_id                        KEY               TIMESTAMP  \
# 0  ZIOT1001-____-WCM  predicted_time_to_failure 2020-02-25 15:08:38.819
# 1  ZIOT1001-____-WCM  predicted_time_to_failure 2020-02-25 15:12:41.015
# 2  ZIOT1001-____-WCM  predicted_time_to_failure 2020-02-25 15:13:39.080
# 3  ZIOT1001-____-WCM  predicted_time_to_failure 2020-02-25 15:18:40.767
# 4  ZIOT1001-____-WCM  predicted_time_to_failure 2020-02-25 15:23:39.000
#
#                  last_update      value_n
# 0 2020-03-30 09:56:23.003802  1358.667193
# 1 2020-03-30 09:56:23.003802   753.213066
# 2 2020-03-30 09:56:23.003802   753.167465
# 3 2020-03-30 09:56:23.003802   753.060735
# 4 2020-03-30 09:56:23.003802   753.571376
# 2020-03-30T09:56:32.333 analytics_service.pmlib.persist.PersistColumns.__init__ DEBUG target_grain=Daily, target_grain_tuple=('1D', [], True), target_table=dm_1016_daily
# 2020-03-30T09:56:32.340 analytics_service.pmlib.persist.PersistColumns.execute DEBUG df_input=shape=(62, 1), index={'id': 'O', 'event_timestamp': '<M8[ns]'}, columns={'daily_predicted_time_to_failure': 'float64'}, head(5)=
#                                    daily_predicted_time_to_failure
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25                           1358.667193
#                   2020-02-26                             76.159989
#                   2020-02-27                            405.344200
#                   2020-03-17                            168.303605
#                   2020-03-21                            168.303605
# 2020-03-30T09:56:32.345 analytics_service.pmlib.persist.PersistColumns.execute DEBUG columns_to_persist=[('value_n', 'daily_predicted_time_to_failure')]
# 2020-03-30T09:56:32.356 analytics_service.pmlib.persist.PersistColumns.execute DEBUG df_stacked=shape=(62, 1), index={'id': 'O', 'event_timestamp': '<M8[ns]', 2: 'O'}, columns={'value_n': 'float64'}, head(5)=
#                                                                        value_n
# id                event_timestamp
# ZIOT1001-____-WCM 2020-02-25      daily_predicted_time_to_failure  1358.667193
#                   2020-02-26      daily_predicted_time_to_failure    76.159989
#                   2020-02-27      daily_predicted_time_to_failure   405.344200
#                   2020-03-17      daily_predicted_time_to_failure   168.303605
#                   2020-03-21      daily_predicted_time_to_failure   168.303605
# 2020-03-30T09:56:32.368 analytics_service.pmlib.persist.PersistColumns.execute DEBUG target_table=dm_1016_daily, df_to_write=shape=(62, 5), index={0: 'int64'}, columns={'entity_id': 'O', 'timestamp': '<M8[ns]', 'key': 'O', 'value_n': 'float64', 'last_update': '<M8[ns]'}, head(5)=
#            entity_id  timestamp                              key      value_n  \
# 0  ZIOT1001-____-WCM 2020-02-25  daily_predicted_time_to_failure  1358.667193
# 1  ZIOT1001-____-WCM 2020-02-26  daily_predicted_time_to_failure    76.159989
# 2  ZIOT1001-____-WCM 2020-02-27  daily_predicted_time_to_failure   405.344200
# 3  ZIOT1001-____-WCM 2020-03-17  daily_predicted_time_to_failure   168.303605
# 4  ZIOT1001-____-WCM 2020-03-21  daily_predicted_time_to_failure   168.303605
#
#                  last_update
# 0 2020-03-30 09:56:32.361585
# 1 2020-03-30 09:56:32.361585
# 2 2020-03-30 09:56:32.361585
# 3 2020-03-30 09:56:32.361585
# 4 2020-03-30 09:56:32.361585
# 2020-03-30T09:56:33.758 analytics_service.pmlib.persist.PersistColumns.execute DEBUG clearing existing data of kpi=daily_predicted_time_to_failure
# 2020-03-30T09:56:34.232 pmlib.api._write_dataframe DEBUG df_before_tosql=shape=(62, 5), index={0: 'int64'}, columns={'entity_id': 'O', 'KEY': 'O', 'TIMESTAMP': '<M8[ns]', 'last_update': '<M8[ns]', 'value_n': 'float64'}, head(5)=
#            entity_id                              KEY  TIMESTAMP  \
# 0  ZIOT1001-____-WCM  daily_predicted_time_to_failure 2020-02-25
# 1  ZIOT1001-____-WCM  daily_predicted_time_to_failure 2020-02-26
# 2  ZIOT1001-____-WCM  daily_predicted_time_to_failure 2020-02-27
# 3  ZIOT1001-____-WCM  daily_predicted_time_to_failure 2020-03-17
# 4  ZIOT1001-____-WCM  daily_predicted_time_to_failure 2020-03-21
#
#                  last_update      value_n
# 0 2020-03-30 09:56:32.361585  1358.667193
# 1 2020-03-30 09:56:32.361585    76.159989
# 2 2020-03-30 09:56:32.361585   405.344200
# 3 2020-03-30 09:56:32.361585   168.303605
# 4 2020-03-30 09:56:32.361585   168.303605
# 'D17CE664-6651-49DF-94C5-C584D8B87E62'

# %% [markdown]
# Once registration succeeds, you can see this newly trained model instance available for the asset group on IBM Maximo APM UI.

# %% [markdown]
# <a id="model-template-internals"></a>
# ## Model Template Internals

# %% [markdown]
# The Time to Failure model has two parts:
# + **transformer the raw data to the input format of the four survival estimators in SROM** (**`TimeToFailureEstimatorSromFeatureExtraction`** class in the cell below)
# + **training the Time to Failure model and do the scoring** (**`TimeToFailureEstimatorSrom`** class in the cell below)
#
# In the following cell, we show the source of Maximo APM PMI - Time to Failure model template.

# %%
class TimeToFailureEstimatorSrom(SromEstimator):
    def get_stages(self):
        from srom.survival_analysis.kaplan_meier import KaplanMeier
        from srom.survival_analysis.cox_regression import CoxRegression
        from srom.survival_analysis.aalen_additive_regression import AalenAdditiveRegression
        from srom.survival_analysis.nelson_aalen import NelsonAalen

        event_column = self.features_for_training[-2]
        duration_column = self.features_for_training[-1]

        self.logger.debug('event_column=%s, duration_column=%s' % (event_column, duration_column))

        km = KaplanMeier(duration_column=duration_column, event_column=event_column)
        cr = CoxRegression(duration_column=duration_column, event_column=event_column)
        aar = AalenAdditiveRegression(duration_column=duration_column, event_column=event_column)
        na = NelsonAalen(duration_column=duration_column, event_column=event_column)
        
        return [
            [km, cr, aar,na]
        ]
    
    def get_param_grid(self):
        from srom.pipeline import SROMParamGrid
        return SROMParamGrid(gridtype='empty')
    
    def get_df_for_training(self, df):
        # this model takes all columns as features, so we have to remove any not intended to be features
        # the original two, installdate and faildate, must be removed explicityly before passing for training
        df = super().get_df_for_training(df)
        return df[[column for column in df.columns if column not in self.features_for_training[0:2]]]

    def predict(self, model, df):
        return model.predict(df)

    def get_prediction_result_value_index(self):
        return [0]
    

class TimeToFailureEstimatorFeatureExtraction(BaseTransformer):
    def __init__(self, installdate_column, faildate_column, event_column, duration_column):
        super().__init__()
        self.logger = get_logger(self)
        self.installdate_column = installdate_column
        self.faildate_column = faildate_column
        self.event_column = event_column
        self.duration_column = duration_column

    def execute(self, df):
        self.logger.debug('df_input: %s' % log_df_info(df, head=5))

        df_indices = df.index.names
        df = df.reset_index()

        # add failure event column
        df[self.event_column] = np.where(pd.isnull(df[self.faildate_column]), 0, 1)

        # now calculate the duration besed on installdate, faildate, and current time
        # 1. if faildate is NA, it must be the one for current time (since last failure or installdate), set its end time to current time
        # 2. for faildate not NA, set the previous faildate as the start time (by shift())
        # 3. for the very first row with faildate, the start time would be NA, set this row's start time to be the asset's installdate
        # 4. calculate the diff of start and end, take days
        # 5. this must be per asset grouping

        duration_start_column = 'calc_date_start'
        duration_end_column = 'calc_date_end'

        df[duration_end_column] = np.where(pd.notna(df[self.faildate_column]), df[self.faildate_column], df[df_indices[1]])
        df = df.sort_values([df_indices[0], duration_end_column])
        df[duration_start_column] = df.groupby([df_indices[0]])[duration_end_column].shift(1)
        df[duration_start_column] = np.where(pd.notna(df[duration_start_column]), df[duration_start_column], df[self.installdate_column])
        df = df.astype({duration_start_column: 'datetime64[ms]'})
        df[self.duration_column] = (df[duration_end_column] - df[duration_start_column]).dt.days

        self.logger.debug('df_duration_calculated: %s' % log_df_info(df, head=5))

        # clean up columns and set index back
        df = df.drop(labels=[duration_start_column, duration_end_column], axis=1, errors='ignore')
        df = df.set_index(df_indices)

        self.logger.debug('df_final: %s' % log_df_info(df, head=5))

        return df


class TimeToFailureAssetGroupPipeline(AssetGroupPipeline):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

        self.model_template_name = 'Predicted Failure Date'

        # exclude labels from normal fillna/dropna logic

        if self.fillna_exclude is None:
            self.fillna_exclude = []
        if self.pipeline_config.features_for_training is not None:
            self.fillna_exclude.extend(self.pipeline_config.features_for_training)
            self.fillna_exclude = list(set(self.fillna_exclude))

        if self.dropna_exclude is None:
            self.dropna_exclude = []
        if self.pipeline_config.features_for_training is not None:
            self.dropna_exclude.extend(self.pipeline_config.features_for_training)
            self.dropna_exclude = list(set(self.dropna_exclude))

        # default aggregation post-processing
        prediction = self.pipeline_config.predictions[0]
        default_post_processing = [
            {
                "functionName": "Maximum",
                "enabled": True,
                "granularity": "Daily",
                "output": {
                    "name": "daily_%s" % prediction
                },
                "input": {
                    "source": prediction
                }
            }
        ]
        if self.post_processing is None:
            self.post_processing = default_post_processing
        else:
            for agg in default_post_processing:
                if agg not in self.post_processing:
                    self.post_processing.append(agg)

    def prepare_execute(self, pipeline, model_config):
        # this model uses transfomer to generate 2 new features to 'replace' the original 2
        # the model does not expect the original 2, so the estimator class above override method 
        # to produce custom df for training, to remove the original 2

        installdate_column = model_config.features_for_training[0]
        faildate_column = model_config.features_for_training[1]
        event_column = 'has_failed'
        duration_column = 'days_run'

        model_config.features_for_training.append(event_column)
        model_config.features_for_training.append(duration_column)

        estimator = TimeToFailureEstimatorSrom(**model_config)
        estimator.add_training_preprocessor(TimeToFailureEstimatorFeatureExtraction(installdate_column=model_config.features_for_training[0], faildate_column=model_config.features_for_training[1], event_column=event_column, duration_column=duration_column))
        pipeline.add_stage(estimator)

    def get_prediction_backtrack(self):
        reset = DateOffset(**{"hour": 0, "minute": 0, "second": 0, "microsecond": 0})
        offset = to_offset('1d')
        return [[reset, offset], [reset]]

    @staticmethod
    def generate_sample_data(sensor_type_name, **kwargs):
        return generate_time_to_failure_data(sensor_type_name=sensor_type_name, **kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-407f535bc437> in <module>
# ----> 1 class TimeToFailureEstimatorSrom(SromEstimator):
#       2     def get_stages(self):
#       3         from srom.survival_analysis.kaplan_meier import KaplanMeier
#       4         from srom.survival_analysis.cox_regression import CoxRegression
#       5         from srom.survival_analysis.aalen_additive_regression import AalenAdditiveRegression
#
# NameError: name 'SromEstimator' is not defined

# %% [markdown]
# ## How to override base class
# If you want to customize some functions in the model template, you can just override the function. For example **`TimeToFailureEstimatorSrom(SromEstimator)`**, It is based on the base class **`SromEstimator`** you can:
# + override the existing method in **`SromEstimator`**, or the base class **`BaseEstimator`** of **`SromEstimator`**
# + add new function like **`get_stages`** to configure Survival Classifiers for the algorithm.
#
#     def get_stages(self):
#         from srom.survival_analysis.kaplan_meier import KaplanMeier
#         from srom.survival_analysis.cox_regression import CoxRegression
#         from srom.survival_analysis.aalen_additive_regression import AalenAdditiveRegression
#         from srom.survival_analysis.nelson_aalen import NelsonAalen
#
#         event_column = self.features_for_training[-2]
#         duration_column = self.features_for_training[-1]
#
#         self.logger.debug('event_column=%s, duration_column=%s' % (event_column, duration_column))
#
#         km = KaplanMeier(duration_column=duration_column, event_column=event_column)
#         cr = CoxRegression(duration_column=duration_column, event_column=event_column)
#         aar = AalenAdditiveRegression(duration_column=duration_column, event_column=event_column)
#         na = NelsonAalen(duration_column=duration_column, event_column=event_column)
#
#         return [
#             [km, cr, aar,na]
#         ]

# %% [markdown]
# #### Base class `SromEstimator`

# %%
class SromEstimator(BaseEstimator):
    def __init__(self, features, targets, predictions, srom_training_options=None, **kwargs):
        super().__init__(features=features, targets=targets, predictions=predictions, **kwargs)
        self._set_srom_training_optins(srom_training_options)

    def _set_srom_training_optins(self, srom_training_options):
        self.srom_training_options = srom_training_options
        if self.srom_training_options is None:
            self.srom_training_options = {}
        if 'verbosity' not in self.srom_training_options:
            self.srom_training_options['verbosity'] = 'low'
        if 'exectype' not in self.srom_training_options:
            self.srom_training_options['exectype'] = 'single_node_complete_search'
        if 'num_option_per_pipeline' not in self.srom_training_options:
            self.srom_training_options['num_option_per_pipeline'] = 1
        if 'max_eval_time_minute' not in self.srom_training_options:
            self.srom_training_options['max_eval_time_minute'] = 1

    def train_model(self, df):
        srom_pipeline = self.create_pipeline()
        srom_pipeline = self.configure_pipeline(srom_pipeline)
        srom_pipeline.set_stages(self.get_stages())

        df_train = df
        if isinstance(srom_pipeline, AnomalyPipeline):
            label = self.features_for_training[0]
            df_train = df[pd.isna(df[label])].drop(labels=label, axis=1, errors='ignore').reset_index(drop=True)
            self.logger.debug('trainX: %s' % log_df_info(df_train, head=5))

            validX = df[pd.notna(df[label])].drop(labels=label, axis=1, errors='ignore').reset_index(drop=True)
            validy = df[pd.notna(df[label])][label].reset_index(drop=True)
            self.logger.debug('validX: %s' % log_df_info(validX, head=5))
            self.logger.debug('validy: %s' % log_df_info(validy, head=5))

            srom_pipeline.execute(
                trainX=df_train, 
                validX=validX, 
                validy=validy, 
                param_grid=self.get_param_grid(), 
                **self.srom_training_options)
        else:
            srom_pipeline.execute(
                df_train, 
                param_grid=self.get_param_grid(), 
                **self.srom_training_options)

        srom_pipeline.fit(df_train)

        return srom_pipeline

    def create_pipeline(self):
        return SROMPipeline()

    def configure_pipeline(self, srom_pipeline):
        return srom_pipeline
